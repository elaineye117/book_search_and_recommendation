# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://fourminutebooks.com/book-summaries/'

headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
result = requests.get(url, headers=headers)
# print(result.content.decode())

soup = BeautifulSoup(result.content, "html.parser")

div_right = soup.find_all('div', class_='w4pl-inner')

# %%
from tqdm import tqdm_notebook as tqdm

# %%
booklist = []
for a in soup.find_all('a',href = True):
    booklist.append(a['href'])

booklisturl = booklist[70:910]

summaries = []

# %%
def get_summary(url):

    link = url
    result_page = requests.get(link, headers=headers)
    soup_page = BeautifulSoup(result_page.content, "html.parser")
    table = soup_page.find('div', class_='entry-content')

    text = table.find('p')
    summary = text.get_text()

    return summary

# %%
for sum in tqdm(booklisturl):
    summaries.append(get_summary(sum))
# Out:
# /Users/yiqiye/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   """Entry point for launching an IPython kernel.
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=840.0), HTML(value='')))

# %%
summary = pd.DataFrame(summaries)
summary.sample()
# Out:
#                                                      0
# 336  1-Sentence-Summary: Insight will help you unde...

# %%
# summary[0] = summary[0].str.replace('1-Sentence-Summary: ', '', regex=True)
summary['response'] = summary['response'].str.replace('1-Sentence-Summary: ', '', regex=True).replace('1-Sentence-Summary:', '', regex=True)

# %%
summary = summary.rename(columns={0: "response"})

# %%
summary
# Out:
#                                               response
# 0    Dataclysm gives powerful motivation for being ...
# 1    Upheaval enlightens you by telling the stories...
# 2    Radical Candor is the ultimate guide to becomi...
# 3    Radical Candor is the ultimate guide to becomi...
# 4    Hillbilly Elegy is the inspiring autobiography...
# ..                                                 ...
# 835  Who Not How will skyrocket your success, happi...
# 836  Who Will Cry When You Die? helps you leave a l...
# 837  Why “A” Students Work For “C” Students contain...
# 838  Why Are We Yelling? will improve your relation...
# 839   Why Is Sex Fun takes a humorous look at the e...
#
# [840 rows x 1 columns]

# %%
# summary.to_csv('summary.txt')

# %%
titles = []

# %%
from tqdm.notebook import tqdm

# %%
def get_title(url):
    link = url
    result_page = requests.get(link, headers=headers)
    soup_page = BeautifulSoup(result_page.content, "html.parser")
    table = soup_page.find('div', class_='entry-content')
    p = table.find('p')
    try:     
        title = p.find('a').get_text()
    except AttributeError:
        title = "no title"
    return title

# %%
for link in tqdm(booklisturl):
    titles.append(get_title(link))
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=840.0), HTML(value='')))

# %%
titles
# Out:
# ['Dataclysm',
#  'Upheaval',
#  'Radical Candor',
#  'Radical Candor',
#  'Hillbilly Elegy',
#  'Mind Over Clutter',
#  'no title',
#  'no title',
#  '10 Days To Faster Reading',
#  '10% Happier',
#  '12 Rules For Life',
#  '13 Things Mentally Strong Parents Don’t Do',
#  '13 Things Mentally Strong People Don’t Do',
#  '21 Days To A Big Idea',
#  '21 Lessons For The 21st Century',
#  '23 Things They Don’t Tell You About Capitalism',
#  '30 Lessons For Loving',
#  '59 Seconds',
#  '60 Seconds & You’re Hired!',
#  '7 Strategies For Wealth And Happiness',
#  'A Beautiful Mind',
#  'A Beginner’s Guide To The End',
#  'A Brief History Of Everyone Who Ever Lived',
#  'A Brief History Of Time',
#  'A Crack In Creation',
#  'A Curious Mind',
#  'A First-Rate Madness',
#  'A Force For Good',
#  'A General Theory Of Love',
#  'A Guide To The Good Life',
#  'A History Of The World In 6 Glasses',
#  'A Message To Garcia',
#  'A Mind For Numbers',
#  'A Monk’s Guide To Happiness',
#  'A More Beautiful Question',
#  'A New Earth',
#  'A People’s History Of The United States',
#  'A Return To Love',
#  'A Short History Of Nearly Everything',
#  'A Splendid Exchange',
#  'A Universe From Nothing',
#  'A Vindication Of The Rights Of Woman',
#  'A Walk In The Woods',
#  'A Whole New Mind',
#  'A Woman of No Importance',
#  'A World In Disarray',
#  'A Year With Peter Drucker',
#  'Abundance',
#  'Accidental Genius',
#  'Accounting Made Simple',
#  'Adaptive Markets',
#  'Affluenza',
#  'Against Empathy',
#  'Age Of Ambition',
#  'Age Of Anger',
#  'Agile Selling',
#  'AI Superpowers',
#  'Alchemy',
#  'Alexander Hamilton',
#  'Alexander The Great',
#  'Algorithms To Live By',
#  'Alibaba',
#  'Alibaba’s World',
#  'All About Love',
#  'All Marketers Are Liars',
#  'Alone Together',
#  'Altered Traits',
#  'Amazon',
#  'Amusing Ourselves To Death',
#  'An American Sickness',
#  'An Astronaut’s Guide To Life On Earth',
#  'An Audience Of One',
#  'An Invisible Thread',
#  'Anatomy Of An Epidemic',
#  'Animal, Vegetable, Miracle',
#  'Antifragile',
#  'Anything You Want',
#  'Are You Fully Charged',
#  'Arise, Awake',
#  'As A Man Thinketh',
#  'Ask',
#  'At Home',
#  'Atomic Habits',
#  'Attached',
#  'Awaken The Giant Within',
#  'Aware',
#  'Bad Blood',
#  'Bad Feminist',
#  'Barbarians At The Gate',
#  'Barking Up The Wrong Tree',
#  'Battle Hymn Of The Tiger Mother',
#  'Be A Free Range Human',
#  'Be Fearless',
#  'Be Obsessed Or Be Average',
#  'Be Our Guest',
#  'Becoming',
#  'Becoming The Boss',
#  'Behave',
#  'Behind The Beautiful Forevers',
#  'Behind The Cloud',
#  'Benjamin Franklin: An American Life',
#  'Best Self',
#  'Better Than Before',
#  'Between The World And Me',
#  'Big Magic',
#  'Big Potential',
#  'Bird By Bird',
#  'Bit Literacy',
#  'Black Box Thinking',
#  'Blink',
#  'Blitzscaling',
#  'Blue Ocean Shift',
#  'Blueprint',
#  'Bold',
#  'Boost!',
#  'Born A Crime',
#  'Born For This',
#  'Born To Run',
#  'Bounce',
#  'Braiding Sweetgrass',
#  'Brain Rules',
#  'Brainfluence',
#  'Brainstorm',
#  'Brandwashed',
#  'Brave',
#  'Braving The Wilderness',
#  'Breakfast With Socrates',
#  'Brief Answers To The Big Questions',
#  'Broadcasting Happiness',
#  'Broke Millennial',
#  'Brotopia',
#  'Buddha’s Brain',
#  'Building A StoryBrand',
#  'Building Social Business',
#  'Built To Last',
#  'Built To Sell',
#  'Bullshit Jobs',
#  'Business Adventures',
#  'Business Model Generation',
#  'Buyology',
#  'Call Sign Chaos',
#  'Can’t Hurt Me',
#  'Capitalism And Freedom',
#  'Capitalism',
#  'Carrots And Sticks',
#  'Cashvertising',
#  'Catalyst',
#  'Catch Me If You Can',
#  'Change By Design',
#  'Change Your Questions, Change Your Life',
#  'Chaos Monkeys',
#  'Charlie Munger',
#  'Chasing The Scream',
#  'Chernobyl',
#  'Choose Yourself',
#  'Comfortably Unaware',
#  'Common Sense',
#  'Company Of One',
#  'Confessions Of An Advertising Man',
#  'Conscious Uncoupling',
#  'Contagious',
#  'Content, Inc.',
#  'Cooked',
#  'Cosmos',
#  'Counterclockwise',
#  'Cradle To Cradle',
#  'Creative Confidence',
#  'Creative Schools',
#  'Creativity, Inc.',
#  'Cribsheet',
#  'Crippled America',
#  'Crossing The Chasm',
#  'Crucial Conversations',
#  'Crush It',
#  'Crushing It',
#  'Dare To Lead',
#  'Daring Greatly',
#  'Dark Money',
#  'Dataclysm',
#  'David and Goliath',
#  'Decisive',
#  'Deep Nutrition',
#  'Deep Thinking',
#  'Deep Work',
#  'Delivering Happiness',
#  'Descartes’ Error',
#  'Design To Grow',
#  'Design Your Future',
#  'Designing Your Life',
#  'Difficult Conversations',
#  'Digital Minimalism',
#  'Digital Renaissance',
#  'Disrupt Yourself',
#  'Do Over',
#  'Do The Work',
#  'Do What You Are',
#  'Dollars And Sense',
#  'Don’t Sweat The Small Stuff (… And It’s All Small Stuff)',
#  'Doubt: A History',
#  'Doughnut Economics',
#  'Dreamland',
#  'Drive',
#  'Duct Tape Marketing',
#  'Eat, Move, Sleep',
#  'Eat That Frog',
#  'Eat To Live',
#  'Eating Animals',
#  'Educated',
#  'Ego Is The Enemy',
#  'Einstein: His Life And Universe',
#  'Elon Musk',
#  'Emotional Agility',
#  'Emotional Intelligence',
#  'Empire Of Illusion',
#  'Empty Planet',
#  'Ending Aging',
#  'Energy',
#  'Enlightenment Now',
#  'EntreLeadership',
#  'Epic Content Marketing',
#  'Essentialism',
#  'Everybody Lies',
#  'Everybody Matters',
#  'Everything I Know',
#  'Everything Is F*cked',
#  'Everything Is Figureoutable',
#  'Everything Is Obvious',
#  'Evicted',
#  'Excellent Sheep',
#  'Executive Presence',
#  'Exploring The World Of Lucid Dreaming',
#  'Extraordinary Influence',
#  'Extreme Ownership',
#  ' Facebook Ads Manual',
#  'Factfulness',
#  'Failing Forward',
#  'Faith',
#  'Farmageddon',
#  'Fast Food Nation',
#  'Fear',
#  'Feral',
#  'Find Your Why',
#  'Finding My Virginity',
#  'Finding Your Element',
#  'Finish',
#  'Finite And Infinite Games',
#  'Fire And Fury',
#  'First Bite',
#  'First Things First',
#  'Flourish',
#  'Flow',
#  'Focus',
#  'Food Fix',
#  'Fooled By Randomness',
#  'Forensics: The Anatomy Of Crime',
#  'Founders at Work',
#  'Freakonomics',
#  'Free: The Future Of A Radical Price',
#  'Free To Focus',
#  'From Here To Financial Happiness',
#  'Game Changers',
#  'Genius Foods',
#  'Genius: The Life And Science Of Richard Feynman',
#  'Get Out Of Your Own Way',
#  'Get Smart',
#  'Getting Everything You Can Out Of All You’ve Got',
#  'Getting There',
#  'Getting Things Done',
#  'Ghettoside',
#  'Girl, Stop Apologizing',
#  'Girl, Wash Your Face',
#  '#GIRLBOSS',
#  'Give And Take',
#  'Good To Great',
#  'Grain Brain',
#  'Great At Work',
#  'Great By Choice',
#  'Great Thinkers',
#  'Grit',
#  'Growth Hacker Marketing',
#  'Habits Of A Happy Brain',
#  'Hackers and Painters',
#  'Happier At Home',
#  'Happier',
#  'Happiness',
#  'Hardwiring Happiness',
#  'Hatching Twitter',
#  'Hillbilly Elegy',
#  'Hit Refresh',
#  'Hold Me Tight',
#  'Homo Deus',
#  'Hooked',
#  'How Emotions Are Made',
#  'How Google Works',
#  'How Luck Happens',
#  'How Not To Be Wrong',
#  'How Not To Die',
#  'How Not To Worry',
#  'How Successful People Think',
#  'How To Be A Positive Leader',
#  'How To Be A Stoic',
#  'How To Be Alone',
#  'How To Be An Antiracist',
#  'How To Be Black',
#  'How to Become a Straight-A Student',
#  'How To Change Your Mind',
#  'How To Create A Mind',
#  'How To Do Nothing',
#  'How To Fail At Almost Everything And Still Win Big',
#  ' How To Read A Book',
#  'How To Read Literature Like A Professor',
#  'How To Stop Worrying And Start Living',
#  'How To',
#  'How To Talk To Anyone',
#  'How To Win At The Sport Of Business',
#  'How To Win Friends And Influence People',
#  'How We Got To Now',
#  'How We Learn',
#  'How Will You Measure Your Life',
#  'Howard Hughes: His Life And Madness',
#  'Humans Are Underrated',
#  'I Thought It Was Just Me (But It Isn’t)',
#  'I Wear The Black Hat',
#  'I Will Teach You To Be Rich',
#  'Identity',
#  'If You’re So Smart, Why Aren’t You Happy',
#  'Ignore Everybody',
#  'Ikigai',
#  'Imagine It Forward',
#  'Immunity',
#  'Impeachment',
#  'Imperfect Courage',
#  'In Defense Of Food',
#  'In Search Of Excellence',
#  'Influence',
#  'Inner Engineering',
#  'Insight',
#  'Inventology',
#  'Invisible Influence',
#  'Irresistible',
#  'It Doesn’t Have To Be Crazy At Work',
#  'iWoz',
#  'Jab, Jab, Jab, Right Hook',
#  'Joy At Work',
#  'Just Listen',
#  'Labor of Love',
#  'Launch',
#  'Leaders Eat Last',
#  'Leadershift',
#  'Leadership And Self Deception',
#  'Leadership Strategy And Tactics',
#  'Lean Analytics',
#  'Lean In',
#  'Learned Optimism',
#  'Leonardo Da Vinci',
#  'Less Doing More Living',
#  'Letters From A Stoic',
#  'Liespotting',
#  'Life After Google',
#  'Linchpin',
#  'Living In Your Top 1%',
#  'Long-Term Thinking For A Short-Sighted World',
#  'Long Walk To Freedom',
#  'Losing My Virginity',
#  'Lost Connections',
#  'Loving What Is',
#  'Made To Stick',
#  'Make A Killing On Kindle',
#  'Make Time',
#  'Make Your Bed',
#  'Make Your Mark',
#  'Making Ideas Happen',
#  'Making It All Work',
#  'Man’s Search For Meaning',
#  'Manufacturing Consent',
#  'Mastery',
#  'Maybe You Should Talk To Someone',
#  'Measure What Matters',
#  'Meditations On First Philosophy',
#  'Meditations',
#  'Men Are From Mars, Women Are From Venus',
#  'Merchants of Doubt',
#  'Metahuman',
#  'Million Dollar Consulting',
#  'Millionaire Success Habits',
#  'Mind Gym',
#  'Mind Over Clutter',
#  'Mindset',
#  'Mindsight',
#  'Mini Habits',
#  'Minimalism',
#  'Mistakes Were Made, But Not By Me',
#  'Money: Master The Game',
#  'Money',
#  'Moneyland',
#  'Moonshot!',
#  'Moonwalking With Einstein',
#  'Move Your Bus',
#  'Multipliers',
#  'My Age Of Anxiety',
#  'My Stroke Of Insight',
#  'Napoleon The Great',
#  'Necessary Endings',
#  'Never Eat Alone',
#  'Never Split The Difference',
#  'No-Drama Discipline',
#  'No Excuses!',
#  'Nobody Wants to Read Your Sh*t',
#  'Nonviolent Communication',
#  'Nudge',
#  'On Liberty',
#  'On The Origin Of Species',
#  'On The Shortness Of Life',
#  'On Tyranny',
#  'On Writing Well',
#  'One Simple Idea',
#  'Option B',
#  'Orientalism',
#  'Originals',
#  'Out Of Our Minds',
#  ' Outer Order, Inner Calm',
#  'Outliers',
#  'Outwitting The Devil',
#  'Own The Day, Own Your Life',
#  'Own Your Everyday',
#  'Oxygen',
#  'Pandemic',
#  'Payoff',
#  'Peak: How Great Companies Get Their Mojo From Maslow',
#  'Peak Performance',
#  'Peak',
#  'People Over Profit',
#  'Permission Marketing',
#  'Personality Isn’t Permanent',
#  'Pitch Anything',
#  'Pitch Perfect',
#  'Plato At The Googleplex',
#  'Playing With FIRE',
#  'Pre-Suasion',
#  'Predictable Success',
#  'Predictably Irrational',
#  'Principles',
#  'Problem Solving 101',
#  'Psyched Up',
#  'Psycho-Cybernetics',
#  'Purple Cow',
#  'QBQ!',
#  'Quiet',
#  'Q',
#  'Quitter',
#  'Radical Acceptance',
#  'Radical Candor',
#  'Range',
#  'Reading Like A Writer',
#  'Real Artists Don’t Starve',
#  'Reality Is Broken',
#  'Reasons To Stay Alive',
#  'Reinvent Yourself',
#  'Rejection Proof',
#  'Remote',
#  'Resisting Happiness',
#  'Rest',
#  'Rewire',
#  'Rework',
#  'Rich Dad Poor Dad',
#  'Rising Strong',
#  'Rookie Smarts',
#  'Rule #1',
#  'Salt: A World History',
#  'Salt Sugar Fat',
#  'Sam Walton: Made In America',
#  'Sapiens',
#  'Search Inside Yourself',
#  'Second Chance',
#  'Secrets Of The Millionaire Mind',
#  'See You At The Top',
#  'Self-Compassion',
#  'Selfish Reasons to Have More Kids',
#  'Seven Brief Lessons On Physics',
#  'Sex At Dawn',
#  'Shoe Dog',
#  'Side Hustle',
#  'Silent Spring',
#  'Simple Rules',
#  'Singletasking',
#  'Six Thinking Hats',
#  'Skin In The Game',
#  'Sleep Smarter',
#  'Smart People Should Build Things',
#  'Smartcuts',
#  'Smarter Faster Better',
#  'Smarter',
#  'So Good They Can’t Ignore You',
#  'So You Want To Talk About Race',
#  'So You’ve Been Publicly Shamed',
#  'Social Intelligence',
#  'Social',
#  'Solve For Happy',
#  'Spartan Up',
#  'SPIN Selling',
#  'Sprint',
#  'Spy the Lie',
#  'Stamped From The Beginning',
#  'Start Something That Matters',
#  'Start',
#  'Start-Up Nation',
#  'Start With Why',
#  'Startup Growth Engines',
#  'Status Anxiety',
#  'Steal Like An Artist',
#  'Steve Jobs',
#  'Stillness Is The Key',
#  'Storyworthy',
#  'Strengthsfinder 2.0',
#  'Stumbling On Happiness',
#  'Success Through A Positive Mental Attitude',
#  'Suggestible You',
#  'Super Attractor',
#  'Super Brain',
#  'SuperBetter',
#  'Superfreakonomics',
#  'Superintelligence',
#  'Switch',
#  'Talent Is Overrated',
#  'Talk Like TED',
#  'Talking To Strangers',
#  'Team Of Rivals',
#  'TED Talks',
#  'Tell Me More',
#  'Thank You For Being Late',
#  'Thanks For The Feedback',
#  'The $100 Startup',
#  'The 10X Rule',
#  'The 12 Week Year',
#  'The 15 Invaluable Laws Of Growth',
#  'The 21 Irrefutable Laws Of Leadership',
#  'The 22 Immutable Laws Of Marketing',
#  'The 4 Day Week',
#  'The 4 Disciplines Of Execution',
#  'The 4-Hour Body',
#  'The 4-Hour Workweek',
#  'The 4 Pillar Plan',
#  'The 48 Laws Of Power',
#  'The 5 AM Club',
#  'The 5 Levels Of Leadership',
#  'The 5 Love Languages',
#  'The 5 Second Rule',
#  'The 7 Habits Of Highly Effective People',
#  'The 80/20 Principle',
#  'The 8th Habit',
#  'The Achievement Habit',
#  'The ADHD Advantage',
#  'The Advice Trap',
#  'The Age of Empathy',
#  'The Algebra of Happiness',
#  'The Anatomy Of Peace',
#  'The Antidote',
#  'The Art Of Asking',
#  'The Art Of Choosing',
#  'The Art Of Happiness',
#  'The Art Of Learning',
#  'The Art of Non-Conformity',
#  'The Art Of Seduction',
#  'The Art Of Social Media',
#  'The Art Of The Start',
#  'The Art of Thinking Clearly',
#  'The Art Of Travel',
#  'The Art Of War',
#  'The Art Of Work',
#  'The Artist’s Way',
#  'The Audacity Of Hope',
#  'The Autobiography Of Malcolm X',
#  'The Automatic Millionaire',
#  'The Barefoot Investor',
#  'The Beautiful Cure',
#  'The Better Angels Of Our Nature',
#  'The Big Leap',
#  'The Biology of Belief',
#  'The Black Swan',
#  'The Blue Zones Solution',
#  'The Blue Zones',
#  'The Body Keeps The Score',
#  'The Body',
#  'The Book Of Joy',
#  'The Book',
#  'The Book You Wish Your Parents Had Read',
#  'The Botany Of Desire',
#  'The Box',
#  'The Brain That Changes Itself',
#  'The Bulletproof Diet',
#  'The Business Romantic',
#  'The Charisma Myth',
#  'The Checklist Manifesto',
#  'The Chimp Paradox',
#  'The China Study',
#  'The Coaching Habit',
#  'The Code Of The Extraordinary Mind',
#  'The Compound Effect',
#  'The Confidence Code',
#  'The Courage Habit',
#  'The Courage To Be Disliked',
#  'The Creative Habit',
#  'The Culture Code',
#  'The Da Vinci Curse',
#  'The Desire Map',
#  'The Dip',
#  'The E-Myth Revisited',
#  'The Education Of A Value Investor',
#  'The Effective Executive',
#  'The End Of Average',
#  'The End of Jobs',
#  'The End Of Stress',
#  'The Energy Bus',
#  'The Eureka Factor',
#  'The Everything Store',
#  'The Evolution Of Everything',
#  'The Execution Factor',
#  'The Facebook Effect',
#  'The Fifth Agreement',
#  'The Fifth Discipline',
#  'The Fine Art Of Small Talk',
#  'The First 20 Hours',
#  'The Five Dysfunctions of a Team',
#  'The Fortune Cookie Principle',
#  'The Four Agreements',
#  'The Four Steps To The Epiphany',
#  'The Four Tendencies',
#  'The Freaks Shall Inherit The Earth',
#  'The Game',
#  'The Genius Of Birds',
#  'The Geography Of Genius',
#  'The Gifts Of Imperfection',
#  'The Go-Giver',
#  'The Greatest Salesman In The World',
#  'The Habit Blueprint',
#  'The Happiness Advantage',
#  'The Happiness Equation',
#  'The Happiness Hypothesis',
#  'The Happiness Of Pursuit',
#  'The Happiness Project',
#  'The Happy Mind',
#  'The Hard Thing About Hard Things',
#  'The Hero Factor',
#  'The Hidden Life of Trees',
#  'The Honest Truth About Dishonesty',
#  'The Hot Zone',
#  'The House Of Rothschild',
#  'The Idea Factory',
#  'The Immortal Life of Henrietta Lacks',
#  'The In-Between',
#  'The Inner Game Of Tennis',
#  'The Innovator’s Dilemma',
#  'The Innovators',
#  'The Intelligent Investor',
#  'The Interpretation Of Dreams',
#  'The Introvert’s Complete Career Guide',
#  'The Joy Of Movement',
#  'The Language Instinct',
#  'The Latte Factor',
#  'The Laws Of Human Nature',
#  'The Lean Startup',
#  'The Lessons Of History',
#  'The Life-Changing Magic Of Not Giving A F*ck',
#  'The Life-Changing Magic Of Tidying Up',
#  'The Little Book of Common Sense Investing',
#  'The Little Book Of Hygge',
#  'The Little Book of Lykke',
#  'The Little Book That (Still) Beats The Market',
#  'The Long Tail',
#  'The Longevity Project',
#  'The Magic of Math',
#  'The Magic Of Reality',
#  'The Magic of Thinking Big',
#  'The Man Who Fed The World',
#  'The Man Who Solved The Market',
#  'The Messy Middle',
#  'The Millionaire Fastlane',
#  'The Millionaire Next Door',
#  'The Millionaire Real Estate Agent',
#  'The Miracle Equation',
#  'The Miracle Morning',
#  'The Miracle of Mindfulness',
#  'The Monk Who Sold His Ferrari',
#  'The Moral Animal',
#  'The More Of Less',
#  'The Myth Of Multitasking',
#  'The New Trading For A Living',
#  'The Next Right Thing',
#  'The Now Habit',
#  'The Obstacle Is The Way',
#  'The Omnivore’s Dilemma',
#  'The One Minute Manager',
#  'The One-Page Financial Plan',
#  'The ONE Thing',
#  'The Opposite Of Spoiled',
#  'The Order Of Time',
#  'The Organized Mind',
#  'The Paradox Of Choice',
#  'The Passion Paradox',
#  'The Path Made Clear',
#  'The Personal MBA',
#  'The Personality Brokers',
#  'The Plant Paradox',
#  'The Pomodoro Technique',
#  'The Power Of Bad',
#  'The Power Of Broke',
#  'The Power Of Full Engagement',
#  'The Power Of Habit',
#  'The Power Of Less',
#  'The Power Of No',
#  'The Power of Now',
#  'The Power Of Positive Thinking',
#  'The Power Of Showing Up',
#  'The Power Of Starting Something Stupid',
#  'The Power Of The Other',
#  'The Power Of Your Subconscious Mind',
#  'The Power Paradox',
#  'The Practicing Mind',
#  'The Pragmatist’s Guide To Relationships',
#  'The Presence Process',
#  'The Prince',
#  'The Productivity Project',
#  'The Promise Of A Pencil',
#  'The Psychology Of Selling',
#  'The Psychology of Winning',
#  'The Rebel Rules',
#  'The Republic',
#  'The Richest Man In Babylon',
#  'The Ride Of A Lifetime',
#  'The Rise Of Superman',
#  'The Rise',
#  'The Road Back To You',
#  'The Road Less Traveled',
#  'The Road to Character',
#  'The Road To Serfdom',
#  'The Ruthless Elimination Of Hurry',
#  'The Science of Getting Rich',
#  'The Second Mountain',
#  'The Secret Life of Pronouns',
#  'The Secret',
#  'The Self-Made Billionaire Effect',
#  'The Selfish Gene',
#  'The Seven Spiritual Laws Of Success',
#  'The Signal And The Noise',
#  'The Singularity Is Near',
#  'The Six Pillars Of Self-Esteem',
#  'The Sixth Extinction',
#  'The Sleep Revolution',
#  'The Sleep Solution',
#  'The Snowball',
#  'The Social Animal',
#  'The Speed Of Trust',
#  'The Sports Gene',
#  'The Start-Up of You',
#  'The Storytelling Edge',
#  'The Subtle Art Of Not Giving A F*ck',
#  'The Success Principles',
#  'The Sunflower',
#  'The Talent Code',
#  'The Tao of Physics',
#  'The Tao Te Ching',
#  'The Telomere Effect',
#  'The Thank You Economy',
#  'The Third Door',
#  'The Third Wave',
#  'The Tipping Point',
#  'The Total Money Makeover',
#  'The Truth',
#  'The Ultimate Sales Machine',
#  'The Unexpected Joy Of Being Sober',
#  'The Uninhabitable Earth',
#  'The Untethered Soul',
#  'The Upside Of Irrationality',
#  'The Upside Of Stress',
#  'The Upside Of Your Dark Side',
#  'The Varieties Of Religious Experience',
#  'The War Of Art',
#  'The Way Of Zen',
#  'The Willpower Instinct',
#  'The Wisdom Of Crowds',
#  'The Wisdom Of Insecurity',
#  'The Wisdom Of Life',
#  'The World According To Star Wars',
#  'The World Without Us',
#  'The Worry-Free Mind',
#  'The Year Without Pants',
#  'The Yes Brain',
#  'Theory U',
#  'Things A Little Bird Told Me',
#  'Think And Grow Rich',
#  'Think Like A Freak',
#  'Think Small',
#  'Thinking Fast And Slow',
#  'This Is Marketing',
#  'This Is Your Brain On Music',
#  'Thou Shall Prosper',
#  'Thrive',
#  'Through The Language Glass',
#  'Time And How To Spend It',
#  'Tiny Habits',
#  'To Sell Is Human',
#  'Tools Of Titans',
#  'Traction',
#  'Tribal Leadership',
#  'Tribe of Mentors',
#  'Tribes',
#  'Trillion Dollar Coach',
#  'Trust Me, I’m Lying',
#  'Trying Not To Try',
#  'Tubes',
#  'Turning Pro',
#  'Uncertainty',
#  'Unlimited Power',
#  'Unlocking Potential',
#  'Unshakeable',
#  'Upheaval',
#  'Vagabonding',
#  'Walden',
#  'Weird Parenting Wins',
#  'What Color Is Your Parachute',
#  'What Every Body Is Saying',
#  'What Got You Here Won’t Get You There',
#  'What I Know For Sure',
#  'What If',
#  'What The Eyes Don’t See',
#  'What They Don’t Teach You At Harvard Business School',
#  'What to Eat When',
#  'When Bad Things Happen To Good People',
#  'When Breath Becomes Air',
#  'When: The Scientific Secrets of Perfect Timing',
#  'When Things Fall Apart',
#  'When To Rob A Bank',
#  'Where Good Ideas Come From',
#  'Wherever You Go, There You Are',
#  'Who Moved My Cheese',
#  'Who Not How',
#  'Who Will Cry When You Die?',
#  'Why “A” Students Work For “C” Students',
#  'Why Are We Yelling?',
#  'Why Is Sex Fun']

# %%
name = pd.DataFrame(titles)

# %%
books = name.merge(summary, left_index=True, right_index=True)

# %%
books
# Out:
#                                        book  \
# 0                                 Dataclysm
# 1                                  Upheaval
# 2                            Radical Candor
# 3                            Radical Candor
# 4                           Hillbilly Elegy
# ..                                      ...
# 835                             Who Not How
# 836              Who Will Cry When You Die?
# 837  Why “A” Students Work For “C” Students
# 838                     Why Are We Yelling?
# 839                          Why Is Sex Fun
#
#                                               response
# 0    Dataclysm gives powerful motivation for being ...
# 1    Upheaval enlightens you by telling the stories...
# 2    Radical Candor is the ultimate guide to becomi...
# 3    Radical Candor is the ultimate guide to becomi...
# 4    Hillbilly Elegy is the inspiring autobiography...
# ..                                                 ...
# 835  Who Not How will skyrocket your success, happi...
# 836  Who Will Cry When You Die? helps you leave a l...
# 837  Why “A” Students Work For “C” Students contain...
# 838  Why Are We Yelling? will improve your relation...
# 839   Why Is Sex Fun takes a humorous look at the e...
#
# [840 rows x 2 columns]

# %%
books = books.rename(columns={0: "book"})
books.to_csv('summary.txt')

# %%
name = name.drop_duplicates()

# %%
name = pd.DataFrame(name)

# %%
name
# Out:
# (833, 1)

# %%
link = 'https://fourminutebooks.com/the-second-mountain-summary/'
result_page = requests.get(link, headers=headers)
soup_page = BeautifulSoup(result_page.content, "html.parser")
table = soup_page.find('div', class_='entry-meta')
categories = table.find_all('a', rel="category tag")

# %%
book_class = []

# %%
for i in categories:
    a = i.get_text()
    book_class.append(a)

# %%
book_class
# Out:
# ['Culture',
#  'Happiness',
#  'Leadership',
#  'Management',
#  'Motivation & Inspiration',
#  'Philosophy',
#  'Productivity',
#  'Psychology',
#  'Relationships',
#  'Self Improvement',
#  'Society',
#  'Success']

# %%
def get_cat(url):
    book_classes = []
    link = url
    result_page = requests.get(link, headers=headers)
    soup_page = BeautifulSoup(result_page.content, "html.parser")
    table = soup_page.find('div', class_='entry-meta')
    categories = table.find_all('a', rel="category tag")
    for i in categories:
        a = i.get_text()
        book_class.append(a) 
    return book_classes

# %%
class_ = []
for link in tqdm(booklisturl):
    class_.append(get_cat(link))
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=840.0), HTML(value='')))
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-c0850c762159> in <module>
#       1 class_ = []
#       2 for link in tqdm(booklisturl):
# ----> 3     class_.append(get_cat(link))
#
# <ipython-input-36-32d3f28960f2> in get_cat(url)
#       5     soup_page = BeautifulSoup(result_page.content, "html.parser")
#       6     table = soup_page.find('div', class_='entry-meta')
# ----> 7     categories = table.find_all('a', rel="category tag")
#       8     for i in categories:
#       9         a = i.get_text()
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
class_ = []
for j in class_:
    j = str(j)
    classes.append(j)

# %%
classs = pd.DataFrame(classes)

# %%
classs

# %%
file_name = "BooksData3.csv"

# %%
classs.to_csv(file_name )

# %% [markdown]
# ## Annotation

# %%
import pandas as pd
import numpy as np

# %%
#10 topics
#1. I want to be rich
#2. I want to have my own startup -> Entre1, leadership1, busniess1, marketing0.5, career0.5
#3. I want to be happy -> happiness 1, self improvement 1, health 0.5, motivation 1, Career0.5
#4. I want to be healthy -> Self Improvement 0.5, Health 1, Nutrition 1, Psychology 0.5, Fitness 1
#5. how to success in a work place
#6. how to deal with pressure
#7. I want to have a good relationship
#8. I want to be successful
#9. how to be charming
#10. I want to be strong

# %%
df = pd.read_csv("BooksData.csv")

# %% [markdown]
# # 1. I want to be rich -> Entrepreneurship, Self Improvement, Investing, Money, Personal Finance

# %% [markdown]
# rules:
# * 3 points contains 3 or more topics
# * 2 points contains 2 topics
# * 1 points contains 1 topic
# * 0 points contains 0 topic

# %%
category = list(df['book_category'])

# %%
point = 0
annotation = []
for i in tqdm(category):
    a = 0
    if 'Happiness' in i:
        a += 1
    elif 'Self Improvement' in i:
        a += 1
    elif 'Health'in i:
        a += 1
    elif 'Motivation' in i:
        a += 0.5
    elif 'Career' in i:
        a += 0.5
    #4/5 = 0.8, 0.8x3=2.4
    if a > 2.4:
        point = 3
    elif a < 1.6 and a > 0.8:
        point = 2
    elif a > 0 and a< 0.8:
        point = 1
    else:
        point = 0
    annotation.append(point)

# %%
annotation = pd.DataFrame(annotation)

# %%
file_name = 'annotation.csv'
annotation.to_csv(file_name)

# %% [markdown]
# # Model

# %%
import itertools
from nltk.stem import WordNetLemmatizer
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
import string
# Out:
# [nltk_data] Downloading package punkt to /Users/yiqiye/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/yiqiye/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/yiqiye/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/yiqiye/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
df = pd.read_table("summary.txt",delimiter=',',index_col=0) 
df
# Out:
#                                        book  \
# 0                                 Dataclysm
# 1                                  Upheaval
# 2                            Radical Candor
# 3                            Radical Candor
# 4                           Hillbilly Elegy
# ..                                      ...
# 835                             Who Not How
# 836              Who Will Cry When You Die?
# 837  Why “A” Students Work For “C” Students
# 838                     Why Are We Yelling?
# 839                          Why Is Sex Fun
#
#                                               response
# 0    Dataclysm gives powerful motivation for being ...
# 1    Upheaval enlightens you by telling the stories...
# 2    Radical Candor is the ultimate guide to becomi...
# 3    Radical Candor is the ultimate guide to becomi...
# 4    Hillbilly Elegy is the inspiring autobiography...
# ..                                                 ...
# 835  Who Not How will skyrocket your success, happi...
# 836  Who Will Cry When You Die? helps you leave a l...
# 837  Why “A” Students Work For “C” Students contain...
# 838  Why Are We Yelling? will improve your relation...
# 839   Why Is Sex Fun takes a humorous look at the e...
#
# [840 rows x 2 columns]

# %%
with open("summary.txt", "r", encoding="utf8") as temp:
    wiki_3 = temp.readlines() #read in wiki

# %%
other_character = ['','“','”',"'s",'!','``','’',"'",' ',',', '.', '-', '(', ')', '/', ':', "n't", '[', ']',';', '?', '<', '>']
s_2a = set(other_character)
wordnet_lemmatizer = WordNetLemmatizer()
def clean_word_2a(file):
    cleaned = nltk.word_tokenize(file.lower())
    cleaned = [i.strip(string.punctuation) for i in cleaned]
    cleaned_list = []
    for i in cleaned:
        if i not in s_2a:
            cleaned_list.append(i)
    cleaned_list = [wordnet_lemmatizer.lemmatize(i) for i in cleaned_list]
    return cleaned_list

# %%
wiki_list = [clean_word_2a(i) for i in wiki_3]

# %%
s = ' '
a_list = []
for i in wiki_list:
    a = s.join(i)
    a_list.append(a)

# %%
a_list
# Out:
# ['0',
#  '0 dataclysm give powerful motivation for being more honest online by using information collected from the internet to identify what all of u are really like under the veil of anonymity and how we a a society have changed recently',
#  '1 upheaval enlightens you by telling the story of seven country that fell into crisis including how they got there and what they did to get out and identifies the common thread between all of them',
#  '2 radical candor is the ultimate guide to becoming a great leader manager or bos and will teach you how to connect with people push them to be their best know when and how to fire them and create an environment of trust and innovation at work',
#  '3 radical candor is the ultimate guide to becoming a great leader manager or bos and will teach you how to connect with people push them to be their best know when and how to fire them and create an environment of trust and innovation at work',
#  '4 hillbilly elegy is the inspiring autobiography of j.d vance who explains how his life began in poverty and turbulence and what he had to do to beat those difficult circumstance and rise to success',
#  '5 mind over clutter help you take step to improve your mental health physical health and the environment by showing you why having too much junk is so bad for you and outlining how to get rid of it all',
#  '6 you want to read more you are you re on this site you re reading book summary that s great but you also want to learn faster remember better and be able to tell what s important from what s not',
#  '7',
#  '8 1-sentence-summary 10 day to faster reading help you bring your reading skill to the current century even if you ve stopped developing them like most of u with the end of elementary school by helping you select what to read in a better way and giving you actionable technique to read and retain faster and better',
#  '9 1-sentence-summary 10 happier give skeptic an easy in to meditation by taking a very non-fluffy approach to the science behind this mindfulness practice and showing you how and why letting go of your ego is important for living a stress-free life',
#  '10 1-sentence-summary 12 rule for life is a stern story-based and entertaining self-help manual for young people that lay out a set of simple principle that can help u become more disciplined behave better act with integrity and balance our life while enjoying them a much a we can',
#  '11 13 thing mentally strong parent don t do teach parent how to stop being a roadblock to their kid academic behavioral and emotional success by outlining way to develop the right thinking habit',
#  '12 13 thing mentally strong people don t do started a a personal reminder to not give in to bad habit in the face of adversity but turned into a psychological guidebook to help you improve your mental strength and emotional resilience',
#  '13 1-sentence-summary 21 day to a big idea show you how to combine the creative and rational side of your brain to come up with cool new idea and fun way to implement them which might even help you create a sustainable business in the long run in a little a 21 day',
#  '14 1-sentence-summary 21 lesson for the 21st century highlight today s most pressing political cultural and economic challenge created by technology while helping u prepare for an uncertain future',
#  '15,23 thing they don t tell you about capitalism will help you think more clearly about our current economic state by uncovering the hidden consequence of free-market capitalism and offering solution that could give u all a more fair world',
#  '16,30 lesson for loving give the relationship advice of hundred of couple who have stayed together into old age and will teach you how to have happiness and longevity in your love life',
#  '17 1-sentence-summary 59 second show you several self-improvement hack grounded in the science of psychology which you can use to improve your mindset happiness and life in le than a minute',
#  '18 60 second you re hired is a guide to getting your dream job that will help you feel confident in your next interview by teaching you how to impress your interviewer with being concise focusing on your strength and knowing what to do at every step of the process',
#  '19 7 strategy for wealth and happiness is the ultimate guide to improving your wealth through self-discipline action and a positive attitude toward work money and the people around you',
#  '20 a beautiful mind tell the fascinating story of the mathematical genius mental illness and miraculous recovery and success of john nash jr',
#  '21 a beginner s guide to the end is your guide to using the principle of stillness cleaning and grief to prepare for your own or a loved one s death',
#  '22 a brief history of everyone who ever lived give you another important perspective on mankind s past and present through the lens of our gene',
#  '23 1-sentence-summary a brief history of time is stephen hawking s way of explaining the most complex concept and idea of physic such a space time black hole planet star and gravity to the average joe so that even you and i can better understand how our planet wa created where it came from and where it s going',
#  '24 a crack in creation will teach you all about the power of gene editing that is made possible with crispr by detailing how it work the benefit and opportunity it open up and the ethical risk of using it on human',
#  '25 1-sentence-summary a curious mind is an homage to the power of asking question showing you how being curious can change your entire life from the way you do business to how you interact with your loved one or even shape your country',
#  '26 a first-rate madness share the story of many world leader and explains how they prevailed despite their mental illness and struggle showing you how to turn your psychological disadvantage into leadership strength',
#  '27 1-sentence-summary a force for good is a universal call to turn our compassion outward and use it to improve ourselves and the world around u in science religion social issue business and education',
#  '28 a general theory of love will help you reprogram your mind for better emotional intelligence and relationship by teaching you what three psychiatrist have to say about the science of why we experience love and other emotion',
#  '29 1-sentence-summary a guide to the good life is a roadmap for stoicism showing you how you can cultivate this ancient philosophy in your own life why it s useful and what stoic are really about',
#  '30 a history of the world in 6 glass will give you some great conversation starter at your next party by teaching you the origin and impact of the world six favorite drink including beer wine alcoholic spirit tea coffee and soda',
#  '31 a message to garcia teach you how to be the best at your job by becoming a dedicated worker with a good attitude about whatever task your company give you',
#  '32 a mind for number will teach you how to learn math and science more efficiently and get good at them by understanding how your brain absorbs and process information even if these subject don t come naturally to you',
#  '33 a monk s guide to happiness will help you find more joy in life by identifying the mental pitfall you fall into that make it so hard to have and how to shatter the shackle of suffering to finally find inner peace',
#  '34 a more beautiful question will teach you how to ask more and better question showing you the power that the right question have to transform your life for the better',
#  '35 1-sentence-summary a new earth outline a crazy and destructive place we call home but not without showing u that we can all save it together by looking into our mind and detaching ourselves from our ego so we can practice acceptance and enjoyment',
#  '36 a people s history of the united state will help you improve the world by giving you a better understanding of the true sometimes shameful story of this america s rise to power',
#  '37 a return to love will help you let go of resentment fear and anger to have happier and healthier job and relationship by teaching you how to embrace the power of love',
#  '38 1-sentence-summary a short history of nearly everything explains everything we ve learned about our world and the universe so far including how they formed how we learned to make sense of time space and gravity why it s such a miracle that we re alive and how much of our planet is still a complete mystery to u',
#  '39 1-sentence-summary a splendid exchange outline the history of global trade revealing it older than we think ha enabled the progress of civilization and continues to change the world on a daily basis',
#  '40 a universe from nothing will enlarge your knowledge of our expanding universe by showing you how it began what we re learning about it now and what will happen to it in the future',
#  '41 a vindication of the right of woman will help you make the world a more fair place by teaching some of the gender inequality of the eighteenth century',
#  '42 a walk in the wood tell the interesting story of the adventure bill bryson and stephen katz had while walking the beautiful rugged and historic appalachian trail',
#  '43 a whole new mind is your guide to standing out in the competitive workplace by taking advantage of the big-picture skill of the right side of your brain',
#  '44 a woman of no importance tell the fascinating and exciting story of virginia hall an american who became one of the best spy for the ally in world war ii and helped significantly in the defeat of nazi germany',
#  '45 a world in disarray open your mind to way that you make the world more peaceful by guiding you through the major change in global affair since world war ii',
#  '46 1-sentence-summary a year with peter drucker compiles 52 lesson with weekly exercise into one comprehensive year-long curriculum for manager leader and those who aspire to be one or the other based on the teaching of the father of modern management',
#  '47 1-sentence-summary abundance show you the key technological trend being developed today to give you a glimpse of a future that s a lot brighter than you think and help you embrace the optimism we need to make it happen',
#  '48 1-sentence-summary accidental genius introduces you to the concept of freewriting which you can use to solve complex problem exercise your creativity flesh out your idea and even build a catalog of publishable work',
#  '49 accounting made simple is your guide to learning the fundamental chart equation and concept of managing a business s financial statement',
#  '50 adaptive market give you a better understanding of how the movement of money in the world work by outlining the characteristic of the market some of which are more like living creature than you might think',
#  '51 affluenza asserts that the reason we are so unhappy is because of our obsession with consumption and the sickness that it brings upon ourselves and the world around u a well',
#  '52 against empathy explains the problem with society s obsession with empathy and explores it limitation while giving u useful alternative for situation in which it doesn t work',
#  '53 age of ambition explains how china ha gone from impoverished and only developing to a world superpower and economic powerhouse in only the last 30 year',
#  '54 age of anger will help you understand the current state of the world better by explaining how we got to this present situation of upheaval we re in and how we might stand a chance of making thing better',
#  '55 agile selling help you become a great salesperson by identifying how successful people thrive in any sale position with the skill of learning and adapting quickly',
#  '56 ai superpower will help you understand what to expect of the effect that artificial intelligence will have on your future job opportunity by diving into where china and the u the world s two leader in ai are heading with this breakthrough technology',
#  '57 alchemy is your guide to making magic happen in business and life by teaching you how to practice irrational thinking to stand out and come up with powerful solution to your problem and those of others',
#  '58 alexander hamilton will inspire you to boldly use your strength to change the world a it tell the story of a poor orphan who grew to become one of the most intelligent ambitious and influential people in american history',
#  '59 1-sentence-summary alexander the great is one of the latest most updated and contemporary book on the life of the ancient macedonian king who would extend his empire from a little slide of land in greece through persia egypt all the way to india forming the greatest empire the ancient world had ever seen',
#  '60 1-sentence-summary algorithm to live by explains how computer algorithm work why their relevancy isn t limited to the digital world and how you can make better decision by strategically using the right algorithm at the right time for example in dating at home or in the office',
#  '61 alibaba share the inspiring story of jack ma s hard work entrepreneurial vision and smart thinking that helped him build one of the most successful and influential company in the world',
#  '62 1-sentence-summary alibaba s world is an inside look at one of the world s largest e-commerce company from one of it first western employee who served a it vice president and head of international marketing for several year showing how this company turned from startup to global player in just 15 year',
#  '63 all about love teach you how to get more affection and connection in your relationship by explaining why true love is so difficult these day and how to combat the unrealistic expectation society ha set up that make it so hard',
#  '64 1-sentence-summary all marketer are liar is based on the idea that we believe whatever we want to believe and that it s exactly this trait of ours which marketer use and sometimes abuse to sell their product by infusing them with good story – whether they re true or not',
#  '65 alone together is a book that will make you want to have a better relationship with technology by revealing just how much we rely on it and the way our connection to it is growing worse and having negative effect on u all',
#  '66 altered trait explores the science behind meditation technique and the way they benefit and alter our mind and body',
#  '67 amazon will help you make your business better by sharing what made jeff bezos s gigantic company so successful at going from it humble beginning to now dominating the e-commerce market',
#  '68,1-sentence-summary amusing ourselves to death take you through the history of medium to highlight how entertainment s standing in society ha risen to the point where our addiction to it undermines our independent thinking',
#  '69 an american sickness will motivate you to see what you can do to help improve the state of healthcare in the united state by blowing open the recent greed corruption and selfishness of healthcare company',
#  '70 an astronaut s guide to life on earth teach you how to live better by taking lesson from the rigorous requirement of going to outer space and applying them to everyday life',
#  '71 an audience of one is a practical and inspiring manual for creator who want to live from their art showing a simple purpose-driven path to achieve that goal',
#  '72 an invisible thread will help you feel more motivated to be kind to others by sharing the heartwarming story of the incredible friendship between a boy afflicted with poverty and a successful businesswoman',
#  '73 anatomy of an epidemic teach you how to make better decision about your mental health a it uncovers the questionable origin of medication and reveals the interesting connection between psychiatry and pharmaceutical company',
#  '74 animal vegetable miracle give way to improve your health and the environment by learning how to garden cook and eat more fruit and vegetable',
#  '75 1-sentence-summary antifragile reveals how some system thrive from shock volatility and uncertainty instead of breaking from them and how you can adapt more antifragile trait yourself to thrive in an uncertain and chaotic world',
#  '76 1-sentence-summary anything you want teach you how to build a business that s based on who you are and can become anything you want it to be rather than following the traditional path of startup or corporate culture',
#  '77 1-sentence-summary are you fully charged show you the three key to arriving at work and life with a battery that s brimming with happiness and motivation which are energy interaction and meaning and how to implement them in your day',
#  '78 arise awake will inspire you to move forward with your entrepreneurial dream by sharing the inspirational story of six indian entrepreneur and the lesson they learned on the path to success',
#  '79 1-sentence-summary a a man thinketh is an essay and self-help classic which argues that the key to mastering your life is harnessing the power of your thought and help you cultivate the philosophy and attitude of a positive successful person',
#  '80 ask show you a method that help you take the guesswork out of the equation so you can give your customer what they want even if they don t know what they want',
#  '81 1-sentence-summary at home take you on a tour of the modern home using each room a occasion to reminisce about the history of it tradition thus enlightening you with how the amenity and comfort of everyday life you now take for granted have come to be',
#  '82 1-sentence-summary atomic habit is the definitive guide to breaking bad behavior and adopting good one in four step showing you how small incremental everyday routine compound into massive positive change over time',
#  '83 1-sentence-summary attached delivers a scientific explanation why some relationship thrive and steer a clear path over a lifetime while others crash and burn based on the human need for attachment and the three different style of it',
#  '84 1-sentence-summary awaken the giant within is the psychological blueprint you can follow to wake up and start taking control of your life starting in your mind spreading through your body and then all the way through your relationship work and finance until you re the giant you were always meant to be',
#  '85 aware is a comprehensive overview of the far-reaching benefit of meditation rooted in both science and practice enriched with actionable advice on how to practice mindfulness',
#  '86 bad blood is the story of how elizabeth holmes promised the world a medical miracle that actually operated on deception and lie',
#  '87 bad feminist will show you a new way of looking at equality by revealing some not so common idea about race gender and feminism in the united state',
#  '88 barbarian at the gate show you how not to run a business and reveals the shocking greed of corporate america in the 1980s by telling the story of the leveraged buyout of rjr nabisco',
#  '89 1-sentence-summary barking up the wrong tree turn standard success advice on it head by looking at both side of many common argument like confidence extroversion or being nice concluding it s really other factor that decide if we win and we control more of them than we think',
#  '90 battle hymn of the tiger mother open your eye to the potential benefit of tough love by sharing the traditionally chinese parenting style and experience of amy chua',
#  '91 be a free range human inspires you to finally quit that 9-5 job that is sucking the life out of you and begin working for yourself by explaining why the job security doesn t exist anymore helping you discover your passion and identifying the step you need to follow if you want to start a life of freedom and happiness',
#  '92 be fearless show that radical change are more effective than small enhancement and urge u to be bold in trying to make progress',
#  '',
#  '93 be obsessed or be average motivates you to get your heart into your work and live up to your true potential by identifying the thinking pattern and work habit of the passionate successful and driven grant cardone',
#  '94 be our guest show you how to take better care of your customer by outlining the philosophy and system that disney ha for taking care of theirs which have helped it become one of the most successful company in the world',
#  '95 becoming motivates you to move forward with your dream regardless of your circumstance criticism or what people think is normal by sharing the life story of michelle obama',
#  '96 becoming the bos show leader of all kind whether new or experienced how to identify the pitfall that stand in the way of influencing others for the better and overcome them',
#  '97 behave set out to explain the reason behind human behavior good or bad by exploring the influence of brain chemistry and our environment',
#  '98 behind the beautiful forevers will make you more grateful for what you have look for way to tear down corruption in the world and help the poor by sharing the experience of people living in the annawadi slum in india',
#  '99 1-sentence-summary behind the cloud tell the story of salesforce.com one of the biggest and earliest cloud computing software-as-a-service company in the world and how it went from small startup to billion-dollar status',
#  '100,1-sentence-summary benjamin franklin an american life take a thorough look at the life of one of the most influential human that ever lived and explains how he could achieve such greatness in so many different field and area',
#  '101 best self will help you become the hero you ve always wanted to be by teaching you how to be honest with yourself about what you desire identify your toxic anti-self and discover the trait of the greatest possible version of you that you can imagine',
#  '102 1-sentence-summary better than before break down the latest research on how to break bad habit and develop good one in order to help you find your habit tendency and give you a few simple tool to start improving your own habit',
#  '103 between the world and me help u all fight prejudice and prepares young black men in the u for growing up by revealing ta-nehisi coates s reality of life a a black man dealing with racism in america',
#  '104 1-sentence-summary big magic is the book that ll give you the courage you need to pursue your creative interest by showing you how to deal with your fear notice idea and act on them and take the stress out of creation',
#  '105 big potential will show you that the real secret to success and thriving in all aspect of life is developing strong connection with others and treating them in a way that lift them up',
#  '106 bird by bird is ann lamott s guide to using the power of routine being yourself rolling with the punch and many other principle to become a better writer',
#  '107 1-sentence-summary bit literacy show you how to navigate the innumerable stream of digital information that flow towards u every single day and not become paralyzed or a slave to technology thanks to a few simple system to manage your medium',
#  '108 1-sentence-summary black box thinking reveals that all path to success lead through failure and what you can do to change your perspective on it admit your mistake and build your own black box to consistently learn and improve from the feedback failure give you',
#  '109 1-sentence-summary blink explains what happens when you listen to your gut feeling why these snap judgment are often much more efficient than conscious deliberating and how to avoid your intuition leading you to wrong assumption',
#  '110 1-sentence-summary blitzscaling is the strategy some of today s most valuable company have used to achieve huge market share insanely fast growth big profit margin and become corporate giant in a very short time',
#  '111 blue ocean shift guide you through the step to beating out your competition by creating new market that aren t overcrowded',
#  '112 blueprint help you have hope for the goodness of the human race by revealing our biologically wired social tendency that help u survive and thrive by working together',
#  '113 1-sentence-summary bold show you that exponential technology ha democratized the power to change the world and build wealth by putting it into everyone s hand and explains which trend entrepreneur will most benefit from in the future how to capitalize on them and which challenge are really bold enough to impact u all',
#  '114 boost is a guide for becoming more productive at work by using the preparation and performance technique that world-class athlete use to win gold medal',
#  '115 born a crime will inspire you to make great thing happen no matter what circumstance you re born into by revealing the story of how trevor noah grew up a a mixed child in south africa on the way to becoming an adult',
#  '116 1-sentence-summary born for this show you how to find the work you were meant to do which actually might consist of many different form of work over the course of your life by showing you the power of a side hustle proper risk-assessment creating your own job and pursuing all of your passion – one at a time',
#  '117 born to run explains the natural benefit of long-distance running and how you can become a better runner too based on several year of research experience and training',
#  '118 1-sentence-summary bounce show you that training trump talent every time by explaining the science of deliberate practice the mindset of high performer and how you can use those tool to become a master of whichever skill you choose',
#  '119 braiding sweetgrass offer some great way for all of u to take better care of and be more grateful for our planet by explaining the way that native american view and take care of it',
#  '120 brain rule teach you how to become more productive at work and life by giving proven fact about how your mind work better with good sleep exercise and learning with all the sens',
#  '121 brainfluence will help you get more sale by revealing people s subconscious thinking and their motivation in the decision-making process they use when buying',
#  '122 brainstorm is a fascinating look into the teenage brain that explains why adolescent act so hormonally and recklessly',
#  '123 brandwashed will help you make better buying decision by identifying the psychological tool that marketer use to turn your own brain against you and make you think that you need to buy their product',
#  '124 brave will help you have the relationship career and everything else in life that you ve always wanted but have been afraid to go for by teaching you how to become more courageous',
#  '125 1-sentence-summary braving the wilderness offer a four-step process to find true belonging through authenticity bravery trust and vulnerability since it s mostly about learning to stand alone rather than trying to fit in',
#  '126 1-sentence-summary breakfast with socrates take you through an ordinary day in the company of extraordinary mind by linking each part of it to the core message of one of several great philosopher throughout history such a descartes nietzsche marx and even buddha',
#  '127 brief answer to the big question tackle some of the universe s biggest mystery a hawking explores the law that govern the cosmos and the future of humankind',
#  '128 broadcasting happiness is an encouraging resource that will help you boost your health and happiness in your relationship work and community by showing you how to unlock the power of positive word and story',
#  '129 broke millennial show those in their twenty and thirty how to manage their finance so that they can stop scraping by and instead begin to live more confidently when it come to money',
#  '130 brotopia motivates you to be fairer in the workplace a an employee or employer by revealing the sad sexist state of silicon valley',
#  '131 1-sentence-summary buddha s brain explains how world-changing thought leader like moses mohammed jesus gandhi and the buddha altered their brain with the power of their mind and how you can use the latest finding of neuroscience to do the same and become a more positive resilient mindful and happy person',
#  '132 building a storybrand is your guide to turning your sale page and product into an adventure for your client by identifying the seven step to successful storytelling a a company and how to craft the clearest message possible so that they will understand and want to be part of it',
#  '133 building social business will teach you how to change the world for the better by starting a company that doe good for mankind giving you all the answer about how they work and how to begin one of your own',
#  '134,1-sentence-summary built to last examines what lie behind the extraordinary success of 18 visionary company and which principle and idea they ve used to thrive for a century',
#  '135 built to sell show you how to become a successful entrepreneur by explaining the step necessary to grow a small service company and one day sell it',
#  '136 bullshit job asserts that roughly two out of every five people are stuck in work that is bereft of purpose and these worker could suffer psychological damage a a result',
#  '137 business adventure will teach you how to run a company invest in the stock market change job and many other thing by sharing some of the most interesting experience that big company and their leader have had over the last century',
#  '138 business model generation teach you how to start your own company by explaining the detail of matching your customer s need with your product s capability managing finance and everything else involved in the planning stage of entrepreneurship',
#  '139 buyology show you how to spend le money by revealing the psychological trap that company use to hack your brain and get you to purchase their product without you even realizing they re doing it',
#  '140 call sign chaos is a review of u foreign policy through the eye of general jim mattis who led force in afghanistan and iraq',
#  '141 can t hurt me is the story of david goggins who went from being overweight and depressed to becoming a record-breaking athlete inspiring military leader and world-class personal trainer',
#  '142 capitalism and freedom help you understand some of the most important factor protecting your liberty by outlining the government s role in economics and how thing go best when political entity are small and stay out of the flow of money in a country',
#  '143 capitalism show you how the movement of money in the world really work by outlining the dominant system in the world and it origin and future',
#  '144 1-sentence-summary carrot and stick explains how you can harness the power of incentive – carrot and stick – to change your bad behavior improve your self-control and reach your long-term goal',
#  '145 cashvertising teach you how to become an expert at marketing by using technique like using the power of authority following the three step of writing a perfect headline and appealing to the eight basic desire people have instead of spending million on ad',
#  '146 catalyst explains why extraordinary career growth requires the right stimulus at the right time to propel you to the next level and show you how to cultivate them',
#  '147 1-sentence-summary catch me if you can is the story of how frank abagnale one of the most famous con-artists in history faked over eight identity several profession and cashed over 2.5 million of forged check in the 1960s until the police finally caught him at age 21',
#  '148 change by design make you a better problem solver at every aspect of life by outlining the design thinking process that company can use to innovate and improve',
#  '149 change your question change your life will revolutionize your thinking with question that create a learning mindset',
#  '150 1-sentence-summary chaos monkey is a fun behind-the-scenes look that lift the veil on some of the weird mysterious and sometimes questionable practice going on behind closed door of mega startup in silicon valley',
#  '151 1-sentence-summary charlie munger teach you the investment approach and idea about life from warren buffett s business partner and billionaire charlie munger which the two have used for decade to run one of the most successful company in the world',
#  '152 chasing the scream is a scathing review of the failed war on drug explaining it history with surprising statistic and identifying new way that we can think about addiction recovery and drug law',
#  '153 chernobyl teach some fascinating and important history science and leadership lesson by diving into the detail of the event leading up to the worst nuclear disaster in human history and it aftermath',
#  '154 1-sentence-summary choose yourself is a call to give up traditional career path and take your life into your own hand by building good habit creating your own career and making a decision to choose yourself',
#  '155 comfortably unaware is a well-researched compendium on how our food choice and animal agriculture impact the well-being of the whole planet',
#  '156 common sense is a classic piece of u history that will help you see the importance of society coming together to form a fair governmental system and how these idea paved the way for the american revolution',
#  '157 1-sentence-summary company of one will teach you how going small not big when creating your own company will bring you independence income and lot of free time without the hassle of having to manage employee long meeting and forced growth',
#  '158 1-sentence-summary confession of an advertising man is the marketing bible of the 60 written by the father of advertising david ogilvy to inspire a philosophy of honesty hard work and ethical behavior in his industry',
#  '159 conscious uncoupling will improve your love life by showing you how to break up the right way and why thing are going to be okay after you separate from someone you once loved',
#  '160 contagious illustrates why certain idea and product spread better than others by sharing compelling story from the world of business social campaign and medium',
#  '161 1-sentence-summary content inc describes a six-step model you can use to do your marketing long before you need it without even having a product or spending a lot of money so your entrepreneurial venture will be a guaranteed success',
#  '162 cooked is a historical exploration of the human relationship with food and cooking combined with practical idea on how to improve your diet by preparing more of your own food',
#  '163 cosmos will make you smarter by teaching you the basic of how the universe work including our own solar system and it history',
#  '164 counterclockwise is a critical look at current perspective on health with a particular focus on how we can improve our own when we shift from being mindless to mindful',
#  '165 cradle to cradle uncovers the hidden problem with manufacturing how they affect our planet and what you can do to help by becoming eco-efficient',
#  '166 creative confidence help break the mundanity of everyday work and life by exploring the power that being more innovative ha to improve happiness and success in many different area',
#  '167,1-sentence-summary creative school reveals how fundamentally broken our formal education system really is and how we can change our perspective to teach child the competency and thing they actually need to navigate the modern world',
#  '168 1-sentence-summary creativity inc is an instruction manual for instilling inspiration into employee manager and boss by revealing the hidden force that get in the way based on over 30 year of experience of the president of pixar ed catmull',
#  '169 cribsheet is a smart guide on how to make the best parenting choice for you and your child by using an economic perspective and evidence-based advice based on scientific data',
#  '170 crippled america make you a more informed citizen by sharing the political belief and reasoning behind billionaire and businessman donald j trump s plan to make his country great again',
#  '171 1-sentence-summary crossing the chasm give high tech startup a marketing blueprint in order to make their product get the initial traction it need to eventually reach the majority of the market and not die in the chasm between early adopter and pragmatist',
#  '172 crucial conversation will teach you how to avoid conflict and come to positive solution in high-stakes conversation so you can be effective in your personal and professional life',
#  '173 1-sentence-summary crush it is the blueprint you need to turn your passion into your profession and will give you the tool to turn yourself into a brand leverage social medium produce great content and reap the financial benefit of it',
#  '174 1-sentence-summary crushing it is gary vaynerchuk s follow-up to his personal branding manifesto crush it in which he reiterates the importance of a personal brand and show you the endless possibility that come with building one today',
#  '175 1-sentence-summary dare to lead dispels common myth about modern-day workplace culture and show you that true leadership requires nothing but vulnerability value trust and resilience',
#  '176 1-sentence-summary daring greatly is a book about having the courage to be vulnerable in a world where everyone want to appear strong confident and like they know what they re doing',
#  '177 dark money dive into the depth of the greed and corruption in the american political system by revealing the story of the koch brother who have been enabling the ultra-wealthy to influence political decision for decade',
#  '178 dataclysm give powerful motivation for being more honest online by using information collected from the internet to identify what all of u are really like under the veil of anonymity and how we a a society have changed recently',
#  '179 1-sentence-summary david and goliath explains why underdog win in situation where the odds are stacked unfavorably against them and how you can do the same',
#  '180 1-sentence-summary decisive give you a scientific 4-step approach to making better decision in your life and career based on an extensive study of the available literature and research on the topic',
#  '181 deep nutrition will help you get healthier by explaining the danger of modern dieting technique that are actually doing harm to your body and making you sick',
#  '182 deep thinking is a recap of the past fifty year of the information revolution and an attempt to identify where ai technology may lead u',
#  '183 1-sentence-summary deep work proposes that we have lost our ability to focus deeply and immerse ourselves in a complex task showing you how to cultivate this skill again and focus more than ever before with four simple rule',
#  '184 1-sentence-summary delivering happiness explains how mega online shoe retailer zappos built a unique company culture and customer experience worth remembering which turned it into a billion dollar business',
#  '185 descartes error will help you understand why the argument that the mind and body are disconnected is false by using neuroscience and interesting case study to identify how the body and our emotion play a vital role in logical thinking',
#  '186 1-sentence-summary design to grow us coca-cola a an example of how keeping a company stable and flexible at the same time over decade is not only possible but a must to grow and scale your business across the globe',
#  '187 design your future motivates you to get out of your limiting belief and fear that are holding you back from building a life you love by identifying why you got stuck in a career or job you hate and what step you must take to finally live your dream',
#  '188 designing your life will show you how to break the shackle of your mundane 9-5 job by sharing exercise and tip that will direct you towards your true calling that fill you with passion purpose and fulfillment',
#  '189 difficult conversation identifies why we shy away from some conversation more than others and what we can do to navigate them successfully and without stress',
#  '190 digital minimalism show u where to draw the line with technology and how taking time off our digital device is the key to living a focused life in a noisy world',
#  '191 digital renaissance us empirical data to show that the digitization of medium ha led to a flood of art but that it average quality hasn t changed',
#  '192 1-sentence-summary disrupt yourself explains how you can harness the ever-accelerating power of disruptive innovation in your personal life be it to advance your career or to build a company that thrives by embracing your limitation focusing on your strength and staying flexible and curious along the way',
#  '193 1-sentence-summary do over shine a light on the four core skill you need to build an amazing career relationship skill character and hustle and show you how to develop each one of them and use them in different stage of your career',
#  '194 1-sentence-summary do the work is steven pressfield s follow-up to the war of art where he give you actionable tactic and strategy to overcome resistance the force behind procrastination',
#  '195 do what you are will help you discover your personality type and how it can lead you to a more satisfying career that corresponds to your talent and interest',
#  '196 dollar and sense explains why it s so hard to manage money and teach you how to combat false cue and natural desire so you can manage your dollar in better way',
#  '197 1-sentence-summary don t sweat the small stuff … and it s all small stuff will keep you from letting the little stressful thing in life like your email inbox rushing to train and annoying co-worker drive you insane and help you find peace and calm in a stressful world',
#  '198 doubt a history is a fascinating look at the historical influence of doubt on science religion and the way we think today',
#  '199 1-sentence-summary doughnut economics is a wake-up call to transform our capitalist worldview obsessed with growth into a more balanced sustainable perspective that allows both human and our planet to thrive',
#  '200 dreamland blow open the story of the united state opioid crisis from the frustrating greed and oversight that created it how drug dealer accelerated it s spread and what we re doing now to stop it',
#  '201,1-sentence-summary drive explores what ha motivated human throughout history and explains how we shifted from mere survival to the carrot and stick approach that s still practiced today – and why it s outdated',
#  '202,1-sentence-summary duct tape marketing introduces small business to the nut and bolt of marketing in the 21st century by taking them all the way from character profile and strategy through specific marketing tactic to building a great referral system',
#  '203 1-sentence-summary eat move sleep show you that living a long and healthy life is not the result of massive lifestyle change but of lot of small habit which improve the way you sleep eat and exercise and if combined add a whole lot to your health',
#  '204,1-sentence-summary eat that frog provides 21 technique and strategy to stop procrastinating and get more done',
#  '205 eat to live will help you lose weight feel better and live longer by identifying the flaw in what we think is true about nutrition and using science and case study to reveal how certain food affect u for better or worse',
#  '206 eating animal reveals the true burden of the modern-day meat industry that we all bear a a society and detail the environmental health-related and ethical consequence',
#  '207 educated will help you become more grateful for your schooling freedom and normal relationship by explaining the family difficulty that tara westover had to break free of so that she could get her own education',
#  '208 1-sentence-summary ego is the enemy reveals how a tendency that s hardwired into our brain – the belief the world revolves around u and u alone – hold u back from living the life it make u desire so much what we can do to overcome it at every turn and how to achieve true greatness',
#  '209 1-sentence-summary einstein his life and universe take a close look at the life of albert einstein beginning in how his childhood shaped him what his biggest discovery and personal struggle were and how his focus changed in later year without his genius ever fading until his very last moment',
#  '210 1-sentence-summary elon musk is the first official biography of the creator of solarcity spacex and tesla based on over 30 hour of conversation time between author ashlee vance and musk himself highlighting his complicated childhood the way he make decision and navigates the world and how he managed to disrupt multiple industry all with the goal of saving humanity',
#  '211 1-sentence-summary emotional agility provides a new science-backed approach to navigating life s many trial and detour on your path to fulfillment with which you ll face your emotion head on observe them objectively make choice based on your value and slowly tweak your mindset motivation and habit',
#  '212 1-sentence-summary emotional intelligence explains the importance of emotion in your life how they help and hurt your ability to navigate the world followed by practical advice on how to improve your own emotional intelligence and why that is the key to leading a successful life',
#  '213 empire of illusion motivates you to watch le tv and get better at reading by outlining the sharp drop in literacy level in the united state in recent year the negative effect that have followed and the dark future ahead if we continue on this path',
#  '214 empty planet explains why overpopulation alarmist are wrong and how depopulation pose the more imminent threat to the happiness of humanity',
#  '215 1-sentence-summary ending aging describes how the process of aging is like a disease and therefore treatable by outlining the seven primary way in which we age and possible antidote to all of them plus a glimpse into the future of potentially indefinite human life',
#  '216 energy make you smarter by helping you understand where this important aspect of our life come from how we ve used it throughout history to get to where we are today and why we need to be careful about how we consume it so that we can have a better future',
#  '217 1-sentence-summary enlightenment now describes how the value of the enlightenment science reason humanism and progress keep improving our world until today making it a better place day by day despite the negative news',
#  '218 entreleadership provides you with a path to becoming a great leader in your company by identifying the necessary management and entrepreneurial skill',
#  '219 epic content marketing show why traditional method for selling like tv and direct mail are dead and how creating content is the new future of advertising because it actually grab people s attention by focusing on what they care about instead of your product',
#  '220,1-sentence-summary essentialism show you a new approach to productivity and life by allowing you to be extremely selective about the essential thing in your life and then ruthlessly cutting out everything else',
#  '221 everybody lie will expand your mind about the true nature of human being by explaining what big data is how it came to be and how we can use it to understand ourselves better',
#  '222 everybody matter identifies the best way to become successful in business help your team member trust you and enable people to reach their full potential by showing the power of taking better care of your employee a if they were family',
#  '223 1-sentence-summary everything i know ditch all the rule and give you a guide to living a fulfilled and adventurous life that can be infinitely updated stretched expanded and customized based on who you are instead of another do-this-to-get-rich-fast scheme that doesn t work for everyone',
#  '224 everything is f*cked explains what s wrong with our approach towards happiness and give philosophical suggestion that help u make our life worth living',
# ...
#  '768 1-sentence-summary the ultimate sale machine is the legacy chet holmes left to help sale staff all over the world by giving them 12 key strategy to relentlessly focus and execute on in order to at least double their sale',
#  '769 the unexpected joy of being sober will help you have a happier and healthier life by persuasively revealing the many disadvantage of alcohol and the benefit of going without it permanently',
#  '770 the uninhabitable earth explains how humanity s complacency and negligence have put this world on a course to soon be unlivable unless we each do our small part to improve how we care for this beautiful planet we live on',
#  '771 1-sentence-summary the untethered soul describes how you can untie your self from your ego harness your inner energy expand beyond yourself and float through the river of life instead of blocking or fighting it',
#  '772 1-sentence-summary the upside of irrationality show you the many way in which you act irrational while thinking what you re doing make perfect sense and how this irrational behavior can actually be beneficial a long a you use it the right way',
#  '773 1-sentence-summary the upside of stress help you change your mindset from one that avoids anxiety at all cost to a belief that embrace stress a a normal part of life which help you respond to it in better way and actually be healthier',
#  '774 1-sentence-summary the upside of your dark side take a look at our darkest emotion like anxiety or anger and show you there are real benefit that follow them and their underlying character trait such a narcissism or psychopathy',
#  '775 the variety of religious experience will show you that spirituality isn t limited to church and that you too can benefit from trying a variety of religious practice even if you identify with no religion in particular',
#  '776 1-sentence-summary the war of art brings some much needed tough love to all artist business people and creatives who spend more time battling the resistance against work than actually working by identifying the procrastinating force at play and pulling out the rug from under their foot',
#  '777 the way of zen is the ultimate guide to understanding the history principle and benefit of zen and how it can help u experience mental stillness and enjoy life even in uncertain time',
#  '778 1-sentence-summary the willpower instinct break down willpower into 3 category and give you science-backed system to improve your self-control break bad habit and choose long-term goal over instant gratification',
#  '779 1-sentence-summary the wisdom of crowd research why group reach better decision than individual what make group smart where the danger of group decision lie and how each of u can encourage the group we are part of to work together',
#  '780 1-sentence-summary the wisdom of insecurity is a self-help classic that break down our psychological need for stability and explains how it s led u right into consumerism why that won t solve our problem and how we can really calm our anxiety',
#  '781 1-sentence-summary the wisdom of life is an essay from arthur schopenhauer s last published work which break down happiness into three part and explains how we can achieve it',
#  '782 1-sentence-summary the world according to star war summary examines not only the unrivaled popularity of this epic franchise but also what we can learn from it about the real world about politics law economics and even ourselves',
#  '783 1-sentence-summary the world without u imago planet earth without u human detailing what will happen to nature and man-made creation long after we re gone',
#  '784 the worry-free mind help free you of the shackle of all type of anxiety by identifying where they come from and what step you need to take to regain control of your thinking pattern and become mentally healthy again',
#  '785 1-sentence-summary the year without pant dive into the company culture of automattic the company behind wordpress.com and explains how they ve created a culture of work where employee thrive creativity flow freely and new idea are implemented on a daily basis',
#  '786 the yes brain offer parenting technique that will give your kid an open attitude towards life balance resilience insight and empathy',
#  '787 theory u help leader act based on the future not the past and allows them to create organizational change at a global level through creative and agile methodology',
#  '788 1-sentence-summary thing a little bird told me is twitter co-founder biz stone s look back at the year of his life during and before twitter from which he draw many lesson about business life and society',
#  '789 1-sentence-summary think and grow rich is a curation of the 13 most common habit of wealthy and successful people distilled from studying over 500 individual over the course of 20 year',
#  '790 think like a freak teach you how to reject conventional wisdom a often a possible ask the right question about everything and come up with your own statistically validated answer instead of relying on other people opinion or common sense',
#  '791 think small give the science-backed secret to following through with your goal identifying seven key component that will help you use your own human nature to your advantage for wild success like you ve never had before',
#  '792 1-sentence-summary thinking fast and slow show you how two system in your brain are constantly fighting over control of your behavior and action and teach you the many way in which this lead to error in memory judgment and decision and what you can do about it',
#  '793 this is marketing argues that marketing success in today s world come from focusing more on the need value and desire of our target audience rather than spamming a many people a possible with our message',
#  '794 1-sentence-summary this is your brain on music explains where music historically come from what it trigger in our brain how we develop our taste and why it s a crucial part of our life along with what make great musician great',
#  '795 1-sentence-summary thou shall prosper examines the tried and true principle of age-old jewish tradition for creating a life of wealth prosperity and integrity and combine them with example from the modern world of business to help you live a successful life',
#  '796 1-sentence-summary thrive shine a light on the missing ingredient in our perception of success which includes well-being wonder wisdom and giving and go beyond just money and power which often drive people right into burnout terrible health and unhappiness',
#  '797 1-sentence-summary through the language glass explains how the language you speak fundamentally alters your reality and how nature culture and language have all been intertwined all throughout history',
#  '798 time and how to spend it is your guide to becoming more productive by not focusing on working extra hour but instead using the time off more effectively',
#  '799 tiny habit show you the power of applying small change to your routine to unleash the full power that habit have to make your life better',
#  '800 1-sentence-summary to sell is human show you that selling is part of your life no matter what you do and what a successful salesperson look like in the 21st century with practical idea to help you convince others in a more honest natural and sustainable way',
#  '801 1-sentence-summary tool of titan is a massive compendium of everything tim ferriss ha learned about health wealth and wisdom from interviewing over 200 world-class performer on his podcast the tim ferriss show',
#  '802,1-sentence-summary traction is a roadmap for startup to achieve the exponential growth necessary to survive the first few month and year by looking at 19 way to get traction and a framework to help you pick the best one for your startup',
#  '803 tribal leadership explains the various way people function within organization and teach you how to lead change and improve your organization s culture',
#  '804 1-sentence-summary tribe of mentor is a collection of over 100 mini-interviews where some of the world s most successful people share their idea around habit learning money relationship failure success and life',
#  '805 1-sentence-summary tribe turn you from a sheepwalker into a heretic by giving you the tool to start your own tribe explaining why they re the future of business and showing you that you too can be a leader',
#  '806 trillion dollar coach will help you become a better leader in the office by sharing the life and teaching of businessman bill campbell who helped build multi-billion dollar company in silicon valley',
#  '807 1-sentence-summary trust me i m lying is a marketer s take on how influential blog have truly become why that s something to worry about and how the internet is broken which includes his own confession of how he gamed the very same system to generate press for his client',
#  '808 1-sentence-summary trying not to try explores ancient chinese philosophy to break down the art of being spontaneous which will help you unite your mind and body reach a state of flow and breeze through life like a leaf in a river',
#  '809 1-sentence-summary tube is a behind-the-scenes look at the real tangible physical heart of the internet this elusive and seemingly invisible technology that permeates all of our life on a daily basis',
#  '810 1-sentence-summary turning pro is an inspiring instruction manual that ll help you create the work you were meant to do by dividing your life into two phase the amateur and the professional and getting you from one into the other',
#  '811 1-sentence-summary uncertainty show you that the condition of not knowing is nothing to fear but the birthplace of innovation which if you embrace it while anchoring yourself ha an unlimited potential for growth wealth and happiness',
#  '812 1-sentence-summary unlimited power is a self-help classic which break down how tony robbins ha helped top performer achieve at their highest level and how you can use the same mental and physical tactic to accomplish your biggest goal in life',
#  '813 unlocking potential is a guide that will help you a a leader make a difference in people s life in the long run by learning how to coach people in a way that brings to light their greatest strength and capability',
#  '814 unshakeable distills the essence of world class investor down into four core principle you should follow while investing giving you simple rule and actionable step to follow to make sure your finance flourish',
#  '815 upheaval enlightens you by telling the story of seven country that fell into crisis including how they got there and what they did to get out and identifies the common thread between all of them',
#  '816 1-sentence-summary vagabonding will change your relationship with money and travel by showing you that long-term life on the road isn t reserved for rich people and hippy and will give you the tool you need to start living a life of adventure simplicity and content',
#  '817 1-sentence-summary walden detail henry david thoreau s two-year stay in a self-built cabin by a lake in the wood sharing what he learned about solitude nature work thinking and fulfillment during his break from modern city life',
#  '818 weird parenting win will make you better at raising your kid by sharing some strange way that father and mother have had success with their child helping you see that your intuition might just be the greatest tool you have at your disposal',
#  '819 1-sentence-summary what color is your parachute is a classic for job seeker equipping you with the tool tip and strategy you need to quickly find the right gig in today s fast-moving market',
#  '820 1-sentence-summary what every body is saying is an ex-fbi agent guide to reading non-verbal cue which will help you spot others true intention and feeling even when their mouth are saying something different',
#  '821 what got you here won t get you there help you overcome your personality trait and behavior that stop you from achieving even more success',
#  '822 what i know for sure encourages you to create the life you want by pursuing excellence practicing gratitude and leveraging bad experience to become stronger',
#  '823 what if is a compilation of well-researched science-based answer to some of the craziest hypothetical question you can imagine',
#  '824 what the eye don t see tell the shocking and unfortunate story of the public drinking water crisis in flint michigan and how one woman stood up against government corruption and racism to make a positive difference for the city',
#  '825 what they don t teach you at harvard business school teach why succeeding in business ha le to do with accumulated theoretical knowledge through schooling and book and more about people and communication',
#  '826 what to eat when teach u how food work inside our body and how to feed ourselves in a way that better suit our biology making u healthier and stronger',
#  '827 when bad thing happen to good people explains why even the best of people sometimes suffer from adversity and how we can turn our pain into something meaningful instead of lamenting it',
#  '828 when breath becomes air help you see what s really important by diving into paul kalanithi s life of loving neuroscience literature meaning and his family that ended from cancer in his mid-thirties',
#  '829 1-sentence-summary when the scientific secret of perfect timing break down the science of time so you can stop guessing when to do thing and pick the best time to work eat sleep have your coffee and even quit your job',
#  '830 when thing fall apart give you the confidence to make it through life s inevitable setback by sharing idea and strategy like mindfulness to grow your resilience and come out on top',
#  '831,1-sentence-summary when to rob a bank is a collection of the best of the freakonomics author blog post from over 10 year of blogging about economics in all area of our life',
#  '832 1-sentence-summary where good idea come from describes how the process of innovation is similar to evolution and why good idea have to be shaped over time build on existing platform require connection luck and error and how you can turn something old into something new',
#  '833 1-sentence-summary wherever you go there you are explains what mindfulness is and why it s not reserved for zen practitioner and buddhist monk giving you simple way to practice it in everyday life both formally and informally while helping you avoid the obstacle on your way to a more aware self',
#  '834 1-sentence-summary who moved my cheese tell a parable which you can directly apply to your own life in order to stop fearing what lie ahead and instead thrive in an environment of change and uncertainty',
#  '835 who not how will skyrocket your success happiness and fulfillment in all area of your life by identifying why you re looking at your problem the wrong way and how simply seeking to get the right people to help you will make all the difference',
#  '836 who will cry when you die help you leave a lasting legacy of greatness after you re gone by giving specific tip on how to become the best version of yourself and the kind that make others grateful for all of your contribution to their life and the world',
#  '837 why a student work for c student contains robert kiyosaki s lesson on how the global financial crisis is the result of a lack of education and show parent how to become truly money literate so they can teach their kid to do the same and attain financial freedom',
#  '838 why are we yelling will improve your relationship professional life and the way you view the world by showing you that argument aren t bad but important growing experience if we learn to make them productive',
#  '839 1-sentence-summary why is sex fun take a humorous look at the evolution of human sex life explaining why the way we behave sexually is often odd but necessary for our survival']

# %%
wew = pd.DataFrame(a_list)
wew
# Out:
#                                                      0
# 0                                                    0
# 1    0 dataclysm give powerful motivation for being...
# 2    1 upheaval enlightens you by telling the story...
# 3    2 radical candor is the ultimate guide to beco...
# 4    3 radical candor is the ultimate guide to beco...
# ..                                                 ...
# 840  835 who not how will skyrocket your success ha...
# 841  836 who will cry when you die help you leave a...
# 842  837 why a student work for c student contains ...
# 843  838 why are we yelling will improve your relat...
# 844  839 1-sentence-summary why is sex fun take a h...
#
# [845 rows x 1 columns]

# %%
wew.to_csv('wew.txt')

# %%
with open("tokenized_summary.txt", "r", encoding="utf8") as temp:
    wiki_4 = temp.readlines() #read in wiki

# %%
aces = [suit + '#' for suit in wiki_4]

# %%
aces = pd.DataFrame(aces)

# %%
aces.to_csv('##.txt')

# %% [markdown]
# ## Test app.py

# %%
from flask import Flask, render_template, request
import numpy as np
import pandas as pd
import nltk
from nltk.corpus import stopwords
from rank_bm25 import BM25Okapi
from rank_bm25 import BM25Plus
from rank_bm25 import BM25L
import string
from nltk import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer

# %%
def clean_df(df, column):
    df['response_cleaned'] = df[column].str.lower().replace('[^A-Za-z0-9]+', ' ')
    stop = stopwords.words('english')

    df2 = df.copy()

    df2['response_cleaned'] = df2['response_cleaned'].astype(str)

    df2['response_cleaned'] = df2['response_cleaned'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
    return df2

# %%
df2 = clean_df(df, 'response')
df2
# Out:
#                                        book  \
# 0                                 Dataclysm
# 1                                  Upheaval
# 2                            Radical Candor
# 3                            Radical Candor
# 4                           Hillbilly Elegy
# ..                                      ...
# 835                             Who Not How
# 836              Who Will Cry When You Die?
# 837  Why “A” Students Work For “C” Students
# 838                     Why Are We Yelling?
# 839                          Why Is Sex Fun
#
#                                               response  \
# 0    dataclysm gives powerful motivation for being ...
# 1    upheaval enlightens you by telling the stories...
# 2    radical candor is the ultimate guide to becomi...
# 3    radical candor is the ultimate guide to becomi...
# 4    hillbilly elegy is the inspiring autobiography...
# ..                                                 ...
# 835  who not how will skyrocket your success, happi...
# 836  who will cry when you die? helps you leave a l...
# 837  why “a” students work for “c” students contain...
# 838  why are we yelling? will improve your relation...
# 839   why is sex fun takes a humorous look at the e...
#
#                                       response_cleaned
# 0    dataclysm gives powerful motivation honest onl...
# 1    upheaval enlightens telling stories seven coun...
# 2    radical candor ultimate guide becoming great l...
# 3    radical candor ultimate guide becoming great l...
# 4    hillbilly elegy inspiring autobiography j.d. v...
# ..                                                 ...
# 835  skyrocket success, happiness, fulfillment area...
# 836  cry die? helps leave lasting legacy greatness ...
# 837  “a” students work “c” students contains robert...
# 838  yelling? improve relationships, professional l...
# 839  sex fun takes humorous look evolution human se...
#
# [840 rows x 3 columns]

# %%
df_dict = df2.to_dict()
df_dict
# Out:
# {'book': {0: 'Dataclysm',
#   1: 'Upheaval',
#   2: 'Radical Candor',
#   3: 'Radical Candor',
#   4: 'Hillbilly Elegy',
#   5: 'Mind Over Clutter',
#   6: 'no title',
#   7: 'no title',
#   8: '10 Days To Faster Reading',
#   9: '10% Happier',
#   10: '12 Rules For Life',
#   11: '13 Things Mentally Strong Parents Don’t Do',
#   12: '13 Things Mentally Strong People Don’t Do',
#   13: '21 Days To A Big Idea',
#   14: '21 Lessons For The 21st Century',
#   15: '23 Things They Don’t Tell You About Capitalism',
#   16: '30 Lessons For Loving',
#   17: '59 Seconds',
#   18: '60 Seconds & You’re Hired!',
#   19: '7 Strategies For Wealth And Happiness',
#   20: 'A Beautiful Mind',
#   21: 'A Beginner’s Guide To The End',
#   22: 'A Brief History Of Everyone Who Ever Lived',
#   23: 'A Brief History Of Time',
#   24: 'A Crack In Creation',
#   25: 'A Curious Mind',
#   26: 'A First-Rate Madness',
#   27: 'A Force For Good',
#   28: 'A General Theory Of Love',
#   29: 'A Guide To The Good Life',
#   30: 'A History Of The World In 6 Glasses',
#   31: 'A Message To Garcia',
#   32: 'A Mind For Numbers',
#   33: 'A Monk’s Guide To Happiness',
#   34: 'A More Beautiful Question',
#   35: 'A New Earth',
#   36: 'A People’s History Of The United States',
#   37: 'A Return To Love',
#   38: 'A Short History Of Nearly Everything',
#   39: 'A Splendid Exchange',
#   40: 'A Universe From Nothing',
#   41: 'A Vindication Of The Rights Of Woman',
#   42: 'A Walk In The Woods',
#   43: 'A Whole New Mind',
#   44: 'A Woman of No Importance',
#   45: 'A World In Disarray',
#   46: 'A Year With Peter Drucker',
#   47: 'Abundance',
#   48: 'Accidental Genius',
#   49: 'Accounting Made Simple',
#   50: 'Adaptive Markets',
#   51: 'Affluenza',
#   52: 'Against Empathy',
#   53: 'Age Of Ambition',
#   54: 'Age Of Anger',
#   55: 'Agile Selling',
#   56: 'AI Superpowers',
#   57: 'Alchemy',
#   58: 'Alexander Hamilton',
#   59: 'Alexander The Great',
#   60: 'Algorithms To Live By',
#   61: 'Alibaba',
#   62: 'Alibaba’s World',
#   63: 'All About Love',
#   64: 'All Marketers Are Liars',
#   65: 'Alone Together',
#   66: 'Altered Traits',
#   67: 'Amazon',
#   68: 'Amusing Ourselves To Death',
#   69: 'An American Sickness',
#   70: 'An Astronaut’s Guide To Life On Earth',
#   71: 'An Audience Of One',
#   72: 'An Invisible Thread',
#   73: 'Anatomy Of An Epidemic',
#   74: 'Animal, Vegetable, Miracle',
#   75: 'Antifragile',
#   76: 'Anything You Want',
#   77: 'Are You Fully Charged',
#   78: 'Arise, Awake',
#   79: 'As A Man Thinketh',
#   80: 'Ask',
#   81: 'At Home',
#   82: 'Atomic Habits',
#   83: 'Attached',
#   84: 'Awaken The Giant Within',
#   85: 'Aware',
#   86: 'Bad Blood',
#   87: 'Bad Feminist',
#   88: 'Barbarians At The Gate',
#   89: 'Barking Up The Wrong Tree',
#   90: 'Battle Hymn Of The Tiger Mother',
#   91: 'Be A Free Range Human',
#   92: 'Be Fearless',
#   93: 'Be Obsessed Or Be Average',
#   94: 'Be Our Guest',
#   95: 'Becoming',
#   96: 'Becoming The Boss',
#   97: 'Behave',
#   98: 'Behind The Beautiful Forevers',
#   99: 'Behind The Cloud',
#   100: 'Benjamin Franklin: An American Life',
#   101: 'Best Self',
#   102: 'Better Than Before',
#   103: 'Between The World And Me',
#   104: 'Big Magic',
#   105: 'Big Potential',
#   106: 'Bird By Bird',
#   107: 'Bit Literacy',
#   108: 'Black Box Thinking',
#   109: 'Blink',
#   110: 'Blitzscaling',
#   111: 'Blue Ocean Shift',
#   112: 'Blueprint',
#   113: 'Bold',
#   114: 'Boost!',
#   115: 'Born A Crime',
#   116: 'Born For This',
#   117: 'Born To Run',
#   118: 'Bounce',
#   119: 'Braiding Sweetgrass',
#   120: 'Brain Rules',
#   121: 'Brainfluence',
#   122: 'Brainstorm',
#   123: 'Brandwashed',
#   124: 'Brave',
#   125: 'Braving The Wilderness',
#   126: 'Breakfast With Socrates',
#   127: 'Brief Answers To The Big Questions',
#   128: 'Broadcasting Happiness',
#   129: 'Broke Millennial',
#   130: 'Brotopia',
#   131: 'Buddha’s Brain',
#   132: 'Building A StoryBrand',
#   133: 'Building Social Business',
#   134: 'Built To Last',
#   135: 'Built To Sell',
#   136: 'Bullshit Jobs',
#   137: 'Business Adventures',
#   138: 'Business Model Generation',
#   139: 'Buyology',
#   140: 'Call Sign Chaos',
#   141: 'Can’t Hurt Me',
#   142: 'Capitalism And Freedom',
#   143: 'Capitalism',
#   144: 'Carrots And Sticks',
#   145: 'Cashvertising',
#   146: 'Catalyst',
#   147: 'Catch Me If You Can',
#   148: 'Change By Design',
#   149: 'Change Your Questions, Change Your Life',
#   150: 'Chaos Monkeys',
#   151: 'Charlie Munger',
#   152: 'Chasing The Scream',
#   153: 'Chernobyl',
#   154: 'Choose Yourself',
#   155: 'Comfortably Unaware',
#   156: 'Common Sense',
#   157: 'Company Of One',
#   158: 'Confessions Of An Advertising Man',
#   159: 'Conscious Uncoupling',
#   160: 'Contagious',
#   161: 'Content, Inc.',
#   162: 'Cooked',
#   163: 'Cosmos',
#   164: 'Counterclockwise',
#   165: 'Cradle To Cradle',
#   166: 'Creative Confidence',
#   167: 'Creative Schools',
#   168: 'Creativity, Inc.',
#   169: 'Cribsheet',
#   170: 'Crippled America',
#   171: 'Crossing The Chasm',
#   172: 'Crucial Conversations',
#   173: 'Crush It',
#   174: 'Crushing It',
#   175: 'Dare To Lead',
#   176: 'Daring Greatly',
#   177: 'Dark Money',
#   178: 'Dataclysm',
#   179: 'David and Goliath',
#   180: 'Decisive',
#   181: 'Deep Nutrition',
#   182: 'Deep Thinking',
#   183: 'Deep Work',
#   184: 'Delivering Happiness',
#   185: 'Descartes’ Error',
#   186: 'Design To Grow',
#   187: 'Design Your Future',
#   188: 'Designing Your Life',
#   189: 'Difficult Conversations',
#   190: 'Digital Minimalism',
#   191: 'Digital Renaissance',
#   192: 'Disrupt Yourself',
#   193: 'Do Over',
#   194: 'Do The Work',
#   195: 'Do What You Are',
#   196: 'Dollars And Sense',
#   197: 'Don’t Sweat The Small Stuff (… And It’s All Small Stuff)',
#   198: 'Doubt: A History',
#   199: 'Doughnut Economics',
#   200: 'Dreamland',
#   201: 'Drive',
#   202: 'Duct Tape Marketing',
#   203: 'Eat, Move, Sleep',
#   204: 'Eat That Frog',
#   205: 'Eat To Live',
#   206: 'Eating Animals',
#   207: 'Educated',
#   208: 'Ego Is The Enemy',
#   209: 'Einstein: His Life And Universe',
#   210: 'Elon Musk',
#   211: 'Emotional Agility',
#   212: 'Emotional Intelligence',
#   213: 'Empire Of Illusion',
#   214: 'Empty Planet',
#   215: 'Ending Aging',
#   216: 'Energy',
#   217: 'Enlightenment Now',
#   218: 'EntreLeadership',
#   219: 'Epic Content Marketing',
#   220: 'Essentialism',
#   221: 'Everybody Lies',
#   222: 'Everybody Matters',
#   223: 'Everything I Know',
#   224: 'Everything Is F*cked',
#   225: 'Everything Is Figureoutable',
#   226: 'Everything Is Obvious',
#   227: 'Evicted',
#   228: 'Excellent Sheep',
#   229: 'Executive Presence',
#   230: 'Exploring The World Of Lucid Dreaming',
#   231: 'Extraordinary Influence',
#   232: 'Extreme Ownership',
#   233: ' Facebook Ads Manual',
#   234: 'Factfulness',
#   235: 'Failing Forward',
#   236: 'Faith',
#   237: 'Farmageddon',
#   238: 'Fast Food Nation',
#   239: 'Fear',
#   240: 'Feral',
#   241: 'Find Your Why',
#   242: 'Finding My Virginity',
#   243: 'Finding Your Element',
#   244: 'Finish',
#   245: 'Finite And Infinite Games',
#   246: 'Fire And Fury',
#   247: 'First Bite',
#   248: 'First Things First',
#   249: 'Flourish',
#   250: 'Flow',
#   251: 'Focus',
#   252: 'Food Fix',
#   253: 'Fooled By Randomness',
#   254: 'Forensics: The Anatomy Of Crime',
#   255: 'Founders at Work',
#   256: 'Freakonomics',
#   257: 'Free: The Future Of A Radical Price',
#   258: 'Free To Focus',
#   259: 'From Here To Financial Happiness',
#   260: 'Game Changers',
#   261: 'Genius Foods',
#   262: 'Genius: The Life And Science Of Richard Feynman',
#   263: 'Get Out Of Your Own Way',
#   264: 'Get Smart',
#   265: 'Getting Everything You Can Out Of All You’ve Got',
#   266: 'Getting There',
#   267: 'Getting Things Done',
#   268: 'Ghettoside',
#   269: 'Girl, Stop Apologizing',
#   270: 'Girl, Wash Your Face',
#   271: '#GIRLBOSS',
#   272: 'Give And Take',
#   273: 'Good To Great',
#   274: 'Grain Brain',
#   275: 'Great At Work',
#   276: 'Great By Choice',
#   277: 'Great Thinkers',
#   278: 'Grit',
#   279: 'Growth Hacker Marketing',
#   280: 'Habits Of A Happy Brain',
#   281: 'Hackers and Painters',
#   282: 'Happier At Home',
#   283: 'Happier',
#   284: 'Happiness',
#   285: 'Hardwiring Happiness',
#   286: 'Hatching Twitter',
#   287: 'Hillbilly Elegy',
#   288: 'Hit Refresh',
#   289: 'Hold Me Tight',
#   290: 'Homo Deus',
#   291: 'Hooked',
#   292: 'How Emotions Are Made',
#   293: 'How Google Works',
#   294: 'How Luck Happens',
#   295: 'How Not To Be Wrong',
#   296: 'How Not To Die',
#   297: 'How Not To Worry',
#   298: 'How Successful People Think',
#   299: 'How To Be A Positive Leader',
#   300: 'How To Be A Stoic',
#   301: 'How To Be Alone',
#   302: 'How To Be An Antiracist',
#   303: 'How To Be Black',
#   304: 'How to Become a Straight-A Student',
#   305: 'How To Change Your Mind',
#   306: 'How To Create A Mind',
#   307: 'How To Do Nothing',
#   308: 'How To Fail At Almost Everything And Still Win Big',
#   309: ' How To Read A Book',
#   310: 'How To Read Literature Like A Professor',
#   311: 'How To Stop Worrying And Start Living',
#   312: 'How To',
#   313: 'How To Talk To Anyone',
#   314: 'How To Win At The Sport Of Business',
#   315: 'How To Win Friends And Influence People',
#   316: 'How We Got To Now',
#   317: 'How We Learn',
#   318: 'How Will You Measure Your Life',
#   319: 'Howard Hughes: His Life And Madness',
#   320: 'Humans Are Underrated',
#   321: 'I Thought It Was Just Me (But It Isn’t)',
#   322: 'I Wear The Black Hat',
#   323: 'I Will Teach You To Be Rich',
#   324: 'Identity',
#   325: 'If You’re So Smart, Why Aren’t You Happy',
#   326: 'Ignore Everybody',
#   327: 'Ikigai',
#   328: 'Imagine It Forward',
#   329: 'Immunity',
#   330: 'Impeachment',
#   331: 'Imperfect Courage',
#   332: 'In Defense Of Food',
#   333: 'In Search Of Excellence',
#   334: 'Influence',
#   335: 'Inner Engineering',
#   336: 'Insight',
#   337: 'Inventology',
#   338: 'Invisible Influence',
#   339: 'Irresistible',
#   340: 'It Doesn’t Have To Be Crazy At Work',
#   341: 'iWoz',
#   342: 'Jab, Jab, Jab, Right Hook',
#   343: 'Joy At Work',
#   344: 'Just Listen',
#   345: 'Labor of Love',
#   346: 'Launch',
#   347: 'Leaders Eat Last',
#   348: 'Leadershift',
#   349: 'Leadership And Self Deception',
#   350: 'Leadership Strategy And Tactics',
#   351: 'Lean Analytics',
#   352: 'Lean In',
#   353: 'Learned Optimism',
#   354: 'Leonardo Da Vinci',
#   355: 'Less Doing More Living',
#   356: 'Letters From A Stoic',
#   357: 'Liespotting',
#   358: 'Life After Google',
#   359: 'Linchpin',
#   360: 'Living In Your Top 1%',
#   361: 'Long-Term Thinking For A Short-Sighted World',
#   362: 'Long Walk To Freedom',
#   363: 'Losing My Virginity',
#   364: 'Lost Connections',
#   365: 'Loving What Is',
#   366: 'Made To Stick',
#   367: 'Make A Killing On Kindle',
#   368: 'Make Time',
#   369: 'Make Your Bed',
#   370: 'Make Your Mark',
#   371: 'Making Ideas Happen',
#   372: 'Making It All Work',
#   373: 'Man’s Search For Meaning',
#   374: 'Manufacturing Consent',
#   375: 'Mastery',
#   376: 'Maybe You Should Talk To Someone',
#   377: 'Measure What Matters',
#   378: 'Meditations On First Philosophy',
#   379: 'Meditations',
#   380: 'Men Are From Mars, Women Are From Venus',
#   381: 'Merchants of Doubt',
#   382: 'Metahuman',
#   383: 'Million Dollar Consulting',
#   384: 'Millionaire Success Habits',
#   385: 'Mind Gym',
#   386: 'Mind Over Clutter',
#   387: 'Mindset',
#   388: 'Mindsight',
#   389: 'Mini Habits',
#   390: 'Minimalism',
#   391: 'Mistakes Were Made, But Not By Me',
#   392: 'Money: Master The Game',
#   393: 'Money',
#   394: 'Moneyland',
#   395: 'Moonshot!',
#   396: 'Moonwalking With Einstein',
#   397: 'Move Your Bus',
#   398: 'Multipliers',
#   399: 'My Age Of Anxiety',
#   400: 'My Stroke Of Insight',
#   401: 'Napoleon The Great',
#   402: 'Necessary Endings',
#   403: 'Never Eat Alone',
#   404: 'Never Split The Difference',
#   405: 'No-Drama Discipline',
#   406: 'No Excuses!',
#   407: 'Nobody Wants to Read Your Sh*t',
#   408: 'Nonviolent Communication',
#   409: 'Nudge',
#   410: 'On Liberty',
#   411: 'On The Origin Of Species',
#   412: 'On The Shortness Of Life',
#   413: 'On Tyranny',
#   414: 'On Writing Well',
#   415: 'One Simple Idea',
#   416: 'Option B',
#   417: 'Orientalism',
#   418: 'Originals',
#   419: 'Out Of Our Minds',
#   420: ' Outer Order, Inner Calm',
#   421: 'Outliers',
#   422: 'Outwitting The Devil',
#   423: 'Own The Day, Own Your Life',
#   424: 'Own Your Everyday',
#   425: 'Oxygen',
#   426: 'Pandemic',
#   427: 'Payoff',
#   428: 'Peak: How Great Companies Get Their Mojo From Maslow',
#   429: 'Peak Performance',
#   430: 'Peak',
#   431: 'People Over Profit',
#   432: 'Permission Marketing',
#   433: 'Personality Isn’t Permanent',
#   434: 'Pitch Anything',
#   435: 'Pitch Perfect',
#   436: 'Plato At The Googleplex',
#   437: 'Playing With FIRE',
#   438: 'Pre-Suasion',
#   439: 'Predictable Success',
#   440: 'Predictably Irrational',
#   441: 'Principles',
#   442: 'Problem Solving 101',
#   443: 'Psyched Up',
#   444: 'Psycho-Cybernetics',
#   445: 'Purple Cow',
#   446: 'QBQ!',
#   447: 'Quiet',
#   448: 'Q',
#   449: 'Quitter',
#   450: 'Radical Acceptance',
#   451: 'Radical Candor',
#   452: 'Range',
#   453: 'Reading Like A Writer',
#   454: 'Real Artists Don’t Starve',
#   455: 'Reality Is Broken',
#   456: 'Reasons To Stay Alive',
#   457: 'Reinvent Yourself',
#   458: 'Rejection Proof',
#   459: 'Remote',
#   460: 'Resisting Happiness',
#   461: 'Rest',
#   462: 'Rewire',
#   463: 'Rework',
#   464: 'Rich Dad Poor Dad',
#   465: 'Rising Strong',
#   466: 'Rookie Smarts',
#   467: 'Rule #1',
#   468: 'Salt: A World History',
#   469: 'Salt Sugar Fat',
#   470: 'Sam Walton: Made In America',
#   471: 'Sapiens',
#   472: 'Search Inside Yourself',
#   473: 'Second Chance',
#   474: 'Secrets Of The Millionaire Mind',
#   475: 'See You At The Top',
#   476: 'Self-Compassion',
#   477: 'Selfish Reasons to Have More Kids',
#   478: 'Seven Brief Lessons On Physics',
#   479: 'Sex At Dawn',
#   480: 'Shoe Dog',
#   481: 'Side Hustle',
#   482: 'Silent Spring',
#   483: 'Simple Rules',
#   484: 'Singletasking',
#   485: 'Six Thinking Hats',
#   486: 'Skin In The Game',
#   487: 'Sleep Smarter',
#   488: 'Smart People Should Build Things',
#   489: 'Smartcuts',
#   490: 'Smarter Faster Better',
#   491: 'Smarter',
#   492: 'So Good They Can’t Ignore You',
#   493: 'So You Want To Talk About Race',
#   494: 'So You’ve Been Publicly Shamed',
#   495: 'Social Intelligence',
#   496: 'Social',
#   497: 'Solve For Happy',
#   498: 'Spartan Up',
#   499: 'SPIN Selling',
#   500: 'Sprint',
#   501: 'Spy the Lie',
#   502: 'Stamped From The Beginning',
#   503: 'Start Something That Matters',
#   504: 'Start',
#   505: 'Start-Up Nation',
#   506: 'Start With Why',
#   507: 'Startup Growth Engines',
#   508: 'Status Anxiety',
#   509: 'Steal Like An Artist',
#   510: 'Steve Jobs',
#   511: 'Stillness Is The Key',
#   512: 'Storyworthy',
#   513: 'Strengthsfinder 2.0',
#   514: 'Stumbling On Happiness',
#   515: 'Success Through A Positive Mental Attitude',
#   516: 'Suggestible You',
#   517: 'Super Attractor',
#   518: 'Super Brain',
#   519: 'SuperBetter',
#   520: 'Superfreakonomics',
#   521: 'Superintelligence',
#   522: 'Switch',
#   523: 'Talent Is Overrated',
#   524: 'Talk Like TED',
#   525: 'Talking To Strangers',
#   526: 'Team Of Rivals',
#   527: 'TED Talks',
#   528: 'Tell Me More',
#   529: 'Thank You For Being Late',
#   530: 'Thanks For The Feedback',
#   531: 'The $100 Startup',
#   532: 'The 10X Rule',
#   533: 'The 12 Week Year',
#   534: 'The 15 Invaluable Laws Of Growth',
#   535: 'The 21 Irrefutable Laws Of Leadership',
#   536: 'The 22 Immutable Laws Of Marketing',
#   537: 'The 4 Day Week',
#   538: 'The 4 Disciplines Of Execution',
#   539: 'The 4-Hour Body',
#   540: 'The 4-Hour Workweek',
#   541: 'The 4 Pillar Plan',
#   542: 'The 48 Laws Of Power',
#   543: 'The 5 AM Club',
#   544: 'The 5 Levels Of Leadership',
#   545: 'The 5 Love Languages',
#   546: 'The 5 Second Rule',
#   547: 'The 7 Habits Of Highly Effective People',
#   548: 'The 80/20 Principle',
#   549: 'The 8th Habit',
#   550: 'The Achievement Habit',
#   551: 'The ADHD Advantage',
#   552: 'The Advice Trap',
#   553: 'The Age of Empathy',
#   554: 'The Algebra of Happiness',
#   555: 'The Anatomy Of Peace',
#   556: 'The Antidote',
#   557: 'The Art Of Asking',
#   558: 'The Art Of Choosing',
#   559: 'The Art Of Happiness',
#   560: 'The Art Of Learning',
#   561: 'The Art of Non-Conformity',
#   562: 'The Art Of Seduction',
#   563: 'The Art Of Social Media',
#   564: 'The Art Of The Start',
#   565: 'The Art of Thinking Clearly',
#   566: 'The Art Of Travel',
#   567: 'The Art Of War',
#   568: 'The Art Of Work',
#   569: 'The Artist’s Way',
#   570: 'The Audacity Of Hope',
#   571: 'The Autobiography Of Malcolm X',
#   572: 'The Automatic Millionaire',
#   573: 'The Barefoot Investor',
#   574: 'The Beautiful Cure',
#   575: 'The Better Angels Of Our Nature',
#   576: 'The Big Leap',
#   577: 'The Biology of Belief',
#   578: 'The Black Swan',
#   579: 'The Blue Zones Solution',
#   580: 'The Blue Zones',
#   581: 'The Body Keeps The Score',
#   582: 'The Body',
#   583: 'The Book Of Joy',
#   584: 'The Book',
#   585: 'The Book You Wish Your Parents Had Read',
#   586: 'The Botany Of Desire',
#   587: 'The Box',
#   588: 'The Brain That Changes Itself',
#   589: 'The Bulletproof Diet',
#   590: 'The Business Romantic',
#   591: 'The Charisma Myth',
#   592: 'The Checklist Manifesto',
#   593: 'The Chimp Paradox',
#   594: 'The China Study',
#   595: 'The Coaching Habit',
#   596: 'The Code Of The Extraordinary Mind',
#   597: 'The Compound Effect',
#   598: 'The Confidence Code',
#   599: 'The Courage Habit',
#   600: 'The Courage To Be Disliked',
#   601: 'The Creative Habit',
#   602: 'The Culture Code',
#   603: 'The Da Vinci Curse',
#   604: 'The Desire Map',
#   605: 'The Dip',
#   606: 'The E-Myth Revisited',
#   607: 'The Education Of A Value Investor',
#   608: 'The Effective Executive',
#   609: 'The End Of Average',
#   610: 'The End of Jobs',
#   611: 'The End Of Stress',
#   612: 'The Energy Bus',
#   613: 'The Eureka Factor',
#   614: 'The Everything Store',
#   615: 'The Evolution Of Everything',
#   616: 'The Execution Factor',
#   617: 'The Facebook Effect',
#   618: 'The Fifth Agreement',
#   619: 'The Fifth Discipline',
#   620: 'The Fine Art Of Small Talk',
#   621: 'The First 20 Hours',
#   622: 'The Five Dysfunctions of a Team',
#   623: 'The Fortune Cookie Principle',
#   624: 'The Four Agreements',
#   625: 'The Four Steps To The Epiphany',
#   626: 'The Four Tendencies',
#   627: 'The Freaks Shall Inherit The Earth',
#   628: 'The Game',
#   629: 'The Genius Of Birds',
#   630: 'The Geography Of Genius',
#   631: 'The Gifts Of Imperfection',
#   632: 'The Go-Giver',
#   633: 'The Greatest Salesman In The World',
#   634: 'The Habit Blueprint',
#   635: 'The Happiness Advantage',
#   636: 'The Happiness Equation',
#   637: 'The Happiness Hypothesis',
#   638: 'The Happiness Of Pursuit',
#   639: 'The Happiness Project',
#   640: 'The Happy Mind',
#   641: 'The Hard Thing About Hard Things',
#   642: 'The Hero Factor',
#   643: 'The Hidden Life of Trees',
#   644: 'The Honest Truth About Dishonesty',
#   645: 'The Hot Zone',
#   646: 'The House Of Rothschild',
#   647: 'The Idea Factory',
#   648: 'The Immortal Life of Henrietta Lacks',
#   649: 'The In-Between',
#   650: 'The Inner Game Of Tennis',
#   651: 'The Innovator’s Dilemma',
#   652: 'The Innovators',
#   653: 'The Intelligent Investor',
#   654: 'The Interpretation Of Dreams',
#   655: 'The Introvert’s Complete Career Guide',
#   656: 'The Joy Of Movement',
#   657: 'The Language Instinct',
#   658: 'The Latte Factor',
#   659: 'The Laws Of Human Nature',
#   660: 'The Lean Startup',
#   661: 'The Lessons Of History',
#   662: 'The Life-Changing Magic Of Not Giving A F*ck',
#   663: 'The Life-Changing Magic Of Tidying Up',
#   664: 'The Little Book of Common Sense Investing',
#   665: 'The Little Book Of Hygge',
#   666: 'The Little Book of Lykke',
#   667: 'The Little Book That (Still) Beats The Market',
#   668: 'The Long Tail',
#   669: 'The Longevity Project',
#   670: 'The Magic of Math',
#   671: 'The Magic Of Reality',
#   672: 'The Magic of Thinking Big',
#   673: 'The Man Who Fed The World',
#   674: 'The Man Who Solved The Market',
#   675: 'The Messy Middle',
#   676: 'The Millionaire Fastlane',
#   677: 'The Millionaire Next Door',
#   678: 'The Millionaire Real Estate Agent',
#   679: 'The Miracle Equation',
#   680: 'The Miracle Morning',
#   681: 'The Miracle of Mindfulness',
#   682: 'The Monk Who Sold His Ferrari',
#   683: 'The Moral Animal',
#   684: 'The More Of Less',
#   685: 'The Myth Of Multitasking',
#   686: 'The New Trading For A Living',
#   687: 'The Next Right Thing',
#   688: 'The Now Habit',
#   689: 'The Obstacle Is The Way',
#   690: 'The Omnivore’s Dilemma',
#   691: 'The One Minute Manager',
#   692: 'The One-Page Financial Plan',
#   693: 'The ONE Thing',
#   694: 'The Opposite Of Spoiled',
#   695: 'The Order Of Time',
#   696: 'The Organized Mind',
#   697: 'The Paradox Of Choice',
#   698: 'The Passion Paradox',
#   699: 'The Path Made Clear',
#   700: 'The Personal MBA',
#   701: 'The Personality Brokers',
#   702: 'The Plant Paradox',
#   703: 'The Pomodoro Technique',
#   704: 'The Power Of Bad',
#   705: 'The Power Of Broke',
#   706: 'The Power Of Full Engagement',
#   707: 'The Power Of Habit',
#   708: 'The Power Of Less',
#   709: 'The Power Of No',
#   710: 'The Power of Now',
#   711: 'The Power Of Positive Thinking',
#   712: 'The Power Of Showing Up',
#   713: 'The Power Of Starting Something Stupid',
#   714: 'The Power Of The Other',
#   715: 'The Power Of Your Subconscious Mind',
#   716: 'The Power Paradox',
#   717: 'The Practicing Mind',
#   718: 'The Pragmatist’s Guide To Relationships',
#   719: 'The Presence Process',
#   720: 'The Prince',
#   721: 'The Productivity Project',
#   722: 'The Promise Of A Pencil',
#   723: 'The Psychology Of Selling',
#   724: 'The Psychology of Winning',
#   725: 'The Rebel Rules',
#   726: 'The Republic',
#   727: 'The Richest Man In Babylon',
#   728: 'The Ride Of A Lifetime',
#   729: 'The Rise Of Superman',
#   730: 'The Rise',
#   731: 'The Road Back To You',
#   732: 'The Road Less Traveled',
#   733: 'The Road to Character',
#   734: 'The Road To Serfdom',
#   735: 'The Ruthless Elimination Of Hurry',
#   736: 'The Science of Getting Rich',
#   737: 'The Second Mountain',
#   738: 'The Secret Life of Pronouns',
#   739: 'The Secret',
#   740: 'The Self-Made Billionaire Effect',
#   741: 'The Selfish Gene',
#   742: 'The Seven Spiritual Laws Of Success',
#   743: 'The Signal And The Noise',
#   744: 'The Singularity Is Near',
#   745: 'The Six Pillars Of Self-Esteem',
#   746: 'The Sixth Extinction',
#   747: 'The Sleep Revolution',
#   748: 'The Sleep Solution',
#   749: 'The Snowball',
#   750: 'The Social Animal',
#   751: 'The Speed Of Trust',
#   752: 'The Sports Gene',
#   753: 'The Start-Up of You',
#   754: 'The Storytelling Edge',
#   755: 'The Subtle Art Of Not Giving A F*ck',
#   756: 'The Success Principles',
#   757: 'The Sunflower',
#   758: 'The Talent Code',
#   759: 'The Tao of Physics',
#   760: 'The Tao Te Ching',
#   761: 'The Telomere Effect',
#   762: 'The Thank You Economy',
#   763: 'The Third Door',
#   764: 'The Third Wave',
#   765: 'The Tipping Point',
#   766: 'The Total Money Makeover',
#   767: 'The Truth',
#   768: 'The Ultimate Sales Machine',
#   769: 'The Unexpected Joy Of Being Sober',
#   770: 'The Uninhabitable Earth',
#   771: 'The Untethered Soul',
#   772: 'The Upside Of Irrationality',
#   773: 'The Upside Of Stress',
#   774: 'The Upside Of Your Dark Side',
#   775: 'The Varieties Of Religious Experience',
#   776: 'The War Of Art',
#   777: 'The Way Of Zen',
#   778: 'The Willpower Instinct',
#   779: 'The Wisdom Of Crowds',
#   780: 'The Wisdom Of Insecurity',
#   781: 'The Wisdom Of Life',
#   782: 'The World According To Star Wars',
#   783: 'The World Without Us',
#   784: 'The Worry-Free Mind',
#   785: 'The Year Without Pants',
#   786: 'The Yes Brain',
#   787: 'Theory U',
#   788: 'Things A Little Bird Told Me',
#   789: 'Think And Grow Rich',
#   790: 'Think Like A Freak',
#   791: 'Think Small',
#   792: 'Thinking Fast And Slow',
#   793: 'This Is Marketing',
#   794: 'This Is Your Brain On Music',
#   795: 'Thou Shall Prosper',
#   796: 'Thrive',
#   797: 'Through The Language Glass',
#   798: 'Time And How To Spend It',
#   799: 'Tiny Habits',
#   800: 'To Sell Is Human',
#   801: 'Tools Of Titans',
#   802: 'Traction',
#   803: 'Tribal Leadership',
#   804: 'Tribe of Mentors',
#   805: 'Tribes',
#   806: 'Trillion Dollar Coach',
#   807: 'Trust Me, I’m Lying',
#   808: 'Trying Not To Try',
#   809: 'Tubes',
#   810: 'Turning Pro',
#   811: 'Uncertainty',
#   812: 'Unlimited Power',
#   813: 'Unlocking Potential',
#   814: 'Unshakeable',
#   815: 'Upheaval',
#   816: 'Vagabonding',
#   817: 'Walden',
#   818: 'Weird Parenting Wins',
#   819: 'What Color Is Your Parachute',
#   820: 'What Every Body Is Saying',
#   821: 'What Got You Here Won’t Get You There',
#   822: 'What I Know For Sure',
#   823: 'What If',
#   824: 'What The Eyes Don’t See',
#   825: 'What They Don’t Teach You At Harvard Business School',
#   826: 'What to Eat When',
#   827: 'When Bad Things Happen To Good People',
#   828: 'When Breath Becomes Air',
#   829: 'When: The Scientific Secrets of Perfect Timing',
#   830: 'When Things Fall Apart',
#   831: 'When To Rob A Bank',
#   832: 'Where Good Ideas Come From',
#   833: 'Wherever You Go, There You Are',
#   834: 'Who Moved My Cheese',
#   835: 'Who Not How',
#   836: 'Who Will Cry When You Die?',
#   837: 'Why “A” Students Work For “C” Students',
#   838: 'Why Are We Yelling?',
#   839: 'Why Is Sex Fun'},
#  'response': {0: 'dataclysm gives powerful motivation for being more honest online by using information collected from the internet to identify what all of us are really like under the veil of anonymity and how we as a society have changed recently.',
#   1: 'upheaval enlightens you by telling the stories of seven countries that fell into crises, including how they got there and what they did to get out, and identifies the common threads between all of them.',
#   2: 'radical candor is the ultimate guide to becoming a great leader, manager, or boss, and will teach you how to connect with people, push them to be their best, know when and how to fire them, and create an environment of trust and innovation at work.',
#   3: 'radical candor is the ultimate guide to becoming a great leader, manager, or boss, and will teach you how to connect with people, push them to be their best, know when and how to fire them, and create an environment of trust and innovation at work.',
#   4: 'hillbilly elegy is the inspiring autobiography of j.d. vance who explains how his life began in poverty and turbulence and what he had to do to beat those difficult circumstances and rise to success.',
#   5: 'mind over clutter helps you take steps to improve your mental health, physical health, and the environment by showing you why having too much junk is so bad for you and outlining how to get rid of it all.',
#   6: 'you want to read more. you are. you’re on this site. you’re reading book summaries. that’s great! but you also want to learn faster, remember better, and be able to tell what’s important from what’s not.',
#   7: nan,
#   8: '\xa010 days to faster reading helps you\xa0bring your reading skills to the current century, even if you’ve stopped developing them, like most of us, with the end of elementary school, by helping you select what to read in a better way and giving you actionable techniques to read and retain faster and better.',
#   9: '\xa010% happier gives skeptics an easy “in” to meditation, by taking a very non-fluffy approach to the science behind this mindfulness practice and showing you how and why letting go of your ego is important for living a stress-free life.',
#   10: '\xa012 rules for life is a stern, story-based, and entertaining self-help manual for young people that lays out a set of simple principles that can help us become more disciplined, behave better, act with integrity, and balance our lives while enjoying them as much as we can.',
#   11: '13 things mentally strong parents don’t do teaches parents how to stop being a roadblock to their kids academic, behavioral, and emotional success by outlining ways to develop the right thinking habits.',
#   12: '13 things mentally strong people don’t do started as a personal reminder to not give in to bad habits in the face of adversity, but turned into a psychological guidebook to help you improve your mental strength and emotional resilience.',
#   13: '\xa021 days to a big idea shows you how to combine the creative and rational sides of your brain to come up with cool, new ideas and fun ways to implement them, which might even help you create a sustainable business in the long run, in as little as 21 days.',
#   14: '\xa021 lessons for the 21st century highlights today’s most pressing political, cultural, and economic challenges created by technology\xa0while helping us prepare for an uncertain future.',
#   15: '23 things they don’t tell you about capitalism will help you think more clearly about our current economic state by uncovering the hidden consequences of free-market capitalism and offering solutions that could give us all a more fair world.',
#   16: '30 lessons for loving gives the relationship advice of hundreds of couples who have stayed together into old age and will teach you how to have happiness and longevity in your love life.',
#   17: '\xa059 seconds shows you several self-improvement hacks, grounded in the science of psychology, which you can use to improve your mindset, happiness and life in less than a minute.',
#   18: '60 seconds & you’re hired! is a guide to getting your dream job that will help you feel confident in your next interview by teaching you how to impress your interviewer with being concise, focusing on your strengths, and knowing what to do at every step of the process.',
#   19: '7 strategies for wealth and happiness is the ultimate guide to improving your wealth through self-discipline, action, and a positive attitude toward work, money, and the people around you.',
#   20: 'a beautiful mind tells the fascinating story of the mathematical genius, mental illness, and miraculous recovery and success of john nash jr.',
#   21: 'a beginner’s guide to the end is your guide to using the principles of stillness, cleaning, and grief to prepare for your own or a loved one’s death.',
#   22: 'a brief history of everyone who ever lived gives you another important perspective on mankind’s past and present through the lens of our genes.',
#   23: '\xa0a brief history of time is stephen hawking’s way of explaining the most complex concepts and ideas of physics, such as space, time, black holes, planets, stars and gravity to the average joe, so that even you and i can better understand how our planet was created, where it came from, and where it’s going.',
#   24: 'a crack in creation will teach you all about the power of gene editing that is made possible with crispr by detailing how it works, the benefits and opportunities it opens up, and the ethical risks of using it on humans.',
#   25: '\xa0a curious mind is an homage to the power of asking questions, showing you how being curious can change your entire life, from the way you do business, to how you interact with your loved ones, or even shape your country.',
#   26: 'a first-rate madness shares the stories of many world leaders and explains how they prevailed despite their mental illnesses and struggles, showing you how to turn your psychological disadvantages into leadership strengths.',
#   27: '\xa0a force for good is a universal call to turn our\xa0compassion outward and use it to improve ourselves and the world around us in science, religion, social issues, business and education.',
#   28: 'a general theory of love will help you reprogram your mind for better emotional intelligence and relationships by teaching you what three psychiatrists have to say about the science of why we experience love and other emotions.',
#   29: '\xa0a guide to the good life is a roadmap for stoicism, showing you how you can cultivate this ancient philosophy in your own life, why it’s useful and what stoics are really about.',
#   30: 'a history of the world in 6 glasses will give you some great conversation starters at your next party by teaching you the origins and impact of the worlds six favorite drinks, including beer, wine, alcoholic spirits, tea, coffee, and soda.',
#   31: 'a message to garcia teaches you how to be the best at your job by becoming a dedicated worker with a good attitude about whatever tasks your company gives you.',
#   32: 'a mind for numbers will teach you how to learn math and science more efficiently and get good at them by understanding how your brain absorbs and processes information, even if these subjects don’t come naturally to you.',
#   33: 'a monk’s guide to happiness will help you find more joy in life by identifying the mental pitfalls you fall into that make it so hard to have and how to shatter the shackles of suffering to finally find inner peace.',
#   34: 'a more beautiful question will teach you how to ask more and better questions, showing you the power that the right questions have to transform your life for the better.',
#   35: '\xa0a new earth outlines a crazy and destructive place we call home, but not without showing us that we can all save it together, by looking into our minds and detaching ourselves from our ego, so we can practice acceptance and enjoyment.',
#   36: 'a people’s history of the united states will help you improve the world by giving you a better understanding of the true, sometimes shameful, story of this america’s rise to power.',
#   37: 'a return to love will help you let go of resentment, fear, and anger to have happier and healthier jobs and relationships by teaching you how to embrace the power of love.',
#   38: '\xa0a short history of nearly everything explains everything we’ve learned about our world and the universe so far, including how they formed, how we learned to make sense of time, space and gravity, why it’s such a miracle that we’re alive and how much of our planet is still a complete mystery to us.',
#   39: '\xa0a splendid exchange outlines the history of global trade, revealing its older than we think, has enabled the progress of civilization, and continues to change the world on a daily basis.',
#   40: 'a universe from nothing will enlarge your knowledge of our expanding universe by showing you how it began, what we’re learning about it now, and what will happen to it in the future.',
#   41: 'a vindication of the rights of woman will help you make the world a more fair place by teaching some of the gender inequalities of the eighteenth century.',
#   42: 'a walk in the woods tells the interesting story of the adventures bill bryson and stephen katz had while walking the beautiful, rugged, and historic appalachian trail.',
#   43: 'a whole new mind is your guide to standing out in the competitive workplace by taking advantage of the big-picture skills of the right side of your brain.',
#   44: 'a woman of no importance tells the fascinating and exciting story of virginia hall, an american who became one of the best spies for the allies in world war ii and helped significantly in the defeat of nazi germany.',
#   45: 'a world in disarray opens your mind to ways that you make the world more peaceful by guiding you through the major changes in global affairs since world war ii.',
#   46: '\xa0a year with peter drucker compiles 52 lessons with weekly exercises into one comprehensive, year-long curriculum\xa0for managers, leaders, and those who aspire to be one or the other, based on the teachings of the father of modern management.',
#   47: '\xa0abundance shows you the key technological trends being developed today, to give you a glimpse of a future that’s a lot brighter than you think and help you embrace the optimism we need to make it happen.',
#   48: '\xa0accidental genius\xa0introduces you to the concept of freewriting, which you can use to solve complex problems, exercise your creativity, flesh out your ideas and even build a catalog of publishable work.',
#   49: 'accounting made simple is your guide to learning the fundamental charts, equations, and concepts of managing a business’s financial statements.',
#   50: 'adaptive markets gives you a better understanding of how the movement of money in the world works by outlining the characteristics of the market, some of which are more like living creatures than you might think.',
#   51: 'affluenza asserts that the reason we are so unhappy is because of our obsession with consumption and the sickness that it brings upon ourselves and the world around us as well.',
#   52: 'against empathy explains the problems with society’s obsession with empathy and explores its limitations while giving us useful alternatives for situations in which it doesn’t work.',
#   53: 'age of ambition explains how china has gone from impoverished and only developing to a world superpower and economic powerhouse in only the last 30 years. ',
#   54: 'age of anger will help you understand the current state of the world better by explaining how we got to this present situation of upheaval we’re in and how we might stand a chance of making things better.',
#   55: 'agile selling helps you become a great salesperson by identifying how successful people thrive in any sales position with the skills of learning and adapting quickly.',
#   56: 'ai superpowers will help you understand what to expect of the effect that artificial intelligence will have on your future job opportunities by diving into where china and the us, the world’s two leaders in ai, are heading with this breakthrough technology.',
#   57: 'alchemy is your guide to making magic happen in business and life by teaching you how to practice irrational thinking to stand out and come up with powerful solutions to your problems and those of others. ',
#   58: 'alexander hamilton will inspire you to boldly use your strengths to change the world as it tells the story of a poor orphan who grew to become one of the most intelligent, ambitious, and influential people in american history.',
#   59: '\xa0alexander the great is one of the latest, most updated, and contemporary books on the life of the ancient, macedonian king, who would extend his empire from a little slide of land in greece through persia, egypt, all the way to india, forming the greatest empire the ancient world had ever seen.',
#   60: '\xa0algorithms to live by explains how computer algorithms work, why their relevancy isn’t limited to the digital world and how you can make better decisions by strategically using the right algorithm at the right time, for example in dating, at home or in the office.',
#   61: 'alibaba shares the inspiring story of jack ma’s hard work, entrepreneurial vision, and smart thinking that helped him build one of the most successful and influential companies in the world. ',
#   62: '\xa0alibaba’s world is an inside look at one of the world’s largest e-commerce companies from one of its\xa0first western employees, who served as its vice president and head of international marketing for several years, showing how this company turned from startup to global player in just 15 years.',
#   63: 'all about love teaches you how to get more affection and connection in your relationships by explaining why true love is so difficult these days and how to combat the unrealistic expectations society has set up that makes it so hard.',
#   64: '\xa0all marketers are liars is based on the idea that we believe whatever we want to believe, and that it’s exactly this trait of ours, which marketers use (and sometimes abuse) to sell their products by infusing them with good stories – whether they’re true or not.',
#   65: 'alone together is a book that will make you want to have a better relationship with technology by revealing just how much we rely on it and the ways our connection to it is growing worse and having negative effects on us all.',
#   66: 'altered traits explores the science behind meditation techniques and the way they benefit and alter our mind and body.',
#   67: 'amazon will help you make your business better by sharing what made jeff bezos’s gigantic company so successful at going from its humble beginnings to now dominating the e-commerce market.',
#   68: '\xa0amusing ourselves to death takes you through the history of media to highlight how entertainment’s standing in society has risen to the point where our addiction to it undermines our independent thinking.',
#   69: 'an american sickness will motivate you to see what you can do to help improve the state of healthcare in the united states by blowing open the recent greed, corruption, and selfishness of healthcare companies.',
#   70: 'an astronaut’s guide to life on earth teaches you how to live better by taking lessons from the rigorous requirements of going to outer space and applying them to everyday life. ',
#   71: 'an audience of one is a practical and inspiring manual for creators who want to live from their art, showing a simple, purpose-driven path to achieve that goal.',
#   72: 'an invisible thread will help you feel more motivated to be kind to others by sharing the heartwarming story of the incredible friendship between a boy afflicted with poverty and a successful businesswoman.',
#   73: 'anatomy of an epidemic teaches you how to make better decisions about your mental health as it uncovers the questionable origin of medication and reveals the interesting connection between psychiatry and pharmaceutical companies.',
#   74: 'animal, vegetable, miracle gives ways to improve your health and the environment by learning how to garden, cook, and eat more fruits and vegetables. ',
#   75: '\xa0antifragile reveals how some systems thrive from shocks, volatility and uncertainty, instead of breaking from them, and how you can adapt more antifragile traits yourself to thrive in an uncertain and chaotic world.',
#   76: '\xa0anything you want teaches you how to build a business that’s based on who you are, and can become anything you want it to be, rather than following the traditional paths of startup or corporate culture.',
#   77: '\xa0are you fully charged shows you the three keys to arriving at work and life with a battery that’s brimming with happiness and motivation, which are energy, interactions and meaning, and how to implement them in your day.',
#   78: 'arise, awake will inspire you to move forward with your entrepreneurial dreams by sharing the inspirational stories of six indian entrepreneurs and the lessons they learned on the path to success.',
#   79: '\xa0as a man thinketh is an essay and self-help classic, which argues that the key to mastering your life is harnessing the power of your thoughts and helps you cultivate the philosophy and attitude of a positive, successful person.',
#   80: 'ask shows you a method that helps you take the guesswork out of the equation so you can give your customers what they want even if they don’t know what they want.',
#   81: '\xa0at home takes you on a tour of the modern home, using each room as occasion to reminisce about the history of its tradition, thus enlightening you with how the amenities and comforts of everyday life you now take for granted have come to be.',
#   82: '\xa0atomic habits is the definitive guide to breaking bad behaviors and adopting good ones in four steps, showing you how small, incremental, everyday routines compound into massive, positive change over time.',
#   83: '\xa0attached delivers a scientific explanation why some relationships thrive and steer a clear path over a lifetime, while others crash and burn, based on the human need for attachment and the three different styles of it.',
#   84: '\xa0awaken the giant within is the psychological blueprint you can follow to wake up and start taking control of your life, starting in your mind, spreading through your body and then all the way through your relationships, work and finances until you’re the giant you were always meant to be.',
#   85: 'aware is a comprehensive overview of the far-reaching benefits of meditation, rooted in both science and practice, enriched with actionable advice on how to practice mindfulness. ',
#   86: 'bad blood is the story of how elizabeth holmes promised the world a medical miracle that actually operated on deception and lies. ',
#   87: 'bad feminist will show you a new way of looking at equality by revealing some not so common ideas about race, gender, and feminism in the united states.',
#   88: 'barbarians at the gate shows you how not to run a business and reveals the shocking greed of corporate america in the 1980s by telling the story of the leveraged buyout of rjr nabisco.',
#   89: '\xa0barking up the wrong tree turns standard success advice on its head by looking at both sides of many common arguments, like confidence, extroversion, or being nice, concluding it’s really other factors that decide if we win, and we control more of them than we think.',
#   90: 'battle hymn of the tiger mother opens your eyes to the potential benefits of tough love by sharing the traditionally chinese parenting style and experiences of amy chua.',
#   91: 'be a free range human inspires you to finally quit that 9-5 job that is sucking the life out of you and begin working for yourself by explaining why the “job security” doesn’t exist anymore, helping you discover your passions, and identifying the steps you need to follow if you want to start a life of freedom and happiness.',
#   92: 'be fearless shows that radical changes are more effective than small enhancements and urges us to be bold\xa0in trying to make progress.\n',
#   93: 'be obsessed or be average motivates you to get your heart into your work and live up to your true potential by identifying the thinking patterns and work habits of the passionate, successful, and driven grant cardone.',
#   94: 'be our guest shows you how to take better care of your customers by outlining the philosophy and systems that disney has for taking care of theirs which have helped it become one of the most successful companies in the world.',
#   95: 'becoming motivates you to move forward with your dreams regardless of your circumstances, criticism, or what people think is normal by sharing the life story of michelle obama.',
#   96: 'becoming the boss shows leaders of all kinds, whether new or experienced, how to identify the pitfalls that stand in the way of influencing others for the better and overcome them.',
#   97: 'behave sets out to explain the reason behind human behavior, good or bad, by exploring the influences of brain chemistry and our environment.',
#   98: 'behind the beautiful forevers will make you more grateful for what you have, look for ways to tear down corruption in the world, and help the poor by sharing the experiences of people living in the annawadi slum in india.',
#   99: '\xa0behind the cloud tells the story of salesforce.com, one of the biggest and earliest cloud computing, software-as-a-service companies in the world and how it went from small startup to billion-dollar status.',
#   100: '\xa0benjamin franklin: an american life takes a thorough look at the life of one of the most influential humans that ever lived and explains how he could achieve such greatness in so many different fields and areas.',
#   101: 'best self will help you become the hero you’ve always wanted to be by teaching you how to be honest with yourself about what you desire, identify your toxic anti-self, and discover the traits of the greatest possible version of you that you can imagine.',
#   102: '\xa0better than before breaks down\xa0the latest research on\xa0how to break bad habits and develop good ones, in order to help\xa0you find your habit tendency and give you a few simple tools\xa0to\xa0start improving your own habits.',
#   103: 'between the world and me helps us all fight prejudice and prepares young black men in the us for growing up by revealing ta-nehisi coates’s reality of life as a black man dealing with racism in america.',
#   104: '\xa0big magic is the book that’ll give you the courage you need to pursue your creative interests by showing you how to deal with your fears, notice ideas and act on them and take the stress out of creation.',
#   105: 'big potential will show you that the real secret to success and thriving in all aspects of life is developing strong connections with others and treating them in a way that lifts them up.',
#   106: 'bird by bird is ann lamott’s guide to using the power of routine, being yourself, rolling with the punches, and many other principles to become a better writer.',
# ...
#   741: 'selfish gene explains process evolution biology using genes basic unit, showing manifest form organisms, ensure survival, program brains, strategies worked best throughout history makes humans special context.',
#   742: 'seven spiritual laws success brings together spiritual calmness mindful behavior eastern religions western striving achieving internal external success, showing seven specific ways let come you.',
#   743: 'signal noise explains many predictions end wrong, statisticians, politicians meteorologists fall prey masses data, finding important signals mostly matter cautious, diligent and, importantly, human.',
#   744: 'singularity near outlines future technology describing change keeps accelerating, computers look like made of, biology technology become indistinguishable can’t possibly predict what’ll happen 2045.',
#   745: 'six pillars self-esteem definitive piece one important psychological traits need live happy life, lays introduce six practices life, assert right happy live fulfilling life.',
#   746: 'sixth extinction summarizes human activity contributed mass extinction species points ways mitigate biggest environmental problems.',
#   747: 'sleep revolution paints grim picture western sleep culture, without extending hand school kids, students, professionals ceos alike offering genuine advice stop wearing sleep deprivation badge honor finally get good night’s sleep.',
#   748: 'sleep solution improves quality life identifying myths surrounding rest keep getting it, showing they’re false, teaching establish proper sleep hygiene.',
#   749: 'snowball authorized biography warren buffett, “oracle omaha,” legendary value investor richest man earth, detailing life humble beginnings way unfathomable success.',
#   750: 'social animal weaves social science research story fictional couple shed light decision-making power unconscious minds.',
#   751: 'speed trust explains economics trust, also shows cultivate great trust yourself, relationships, three kinds stakeholders you’ll deal you’re running company.',
#   752: 'sports gene look genes affect abilities, motivations, endurance sports, explaining people better suited certain sports others.',
#   753: 'start-up explains need manage career running start-up get ahead today’s ultra-competitive ever-changing business world.',
#   754: 'storytelling edge boost communication persuasiveness skills showing tell powerful narratives convincing way giving examples should.',
#   755: 'subtle art giving f*ck away positive psychology craze instead give stoic, bullshit approach living life might always happy, meaningful centered around what’s important you.',
#   756: 'success principles condenses 64 lessons jack canfield learned journey becoming successful entrepreneur, author, coach speaker 6 sections, help transform mindset take responsibility control life, get want be.',
#   757: 'sunflower recounts experience holocaust survivor simon wiesenthal, make tough choice whether forgive not, explores 50 different perspectives forgiveness people various religious, cultural ethnic backgrounds.',
#   758: 'talent code cracks open myth talent breaks neurological standpoint three crucial parts, anyone pull together become world-class performer, artist, athlete form something used believe even within hands.',
#   759: 'tao physics questions many biases western science eastern spirituality, showing close connections principles physics buddhism, hinduism, taoism.',
#   760: 'tao te ching helps us understand principles taoism, ancient school philosophy still applicable today.',
#   761: 'telomere effect shows live healthier stay younger longer identifying important part physiology might never heard teaching take great care it.',
#   762: 'thank economy announces return small town courtesy world business, thanks social media, shows business must neglect nurturing one-on-one relationships customers new channels online, thrive modern world.',
#   763: 'third door follows 18-year-old’s wild quest interviewing many world’s successful people discover takes get top.',
#   764: 'third wave lays history internet it’s permeate everything lives, well takes entrepreneurs make use mega-trend thrive omni-connected, always-online world.',
#   765: 'tipping point explains ideas spread like epidemics elements need come together help idea reach point critical mass, viral effect becomes unstoppable.',
#   766: 'total money makeover shows stop accepting debt normal, eliminate forever small increments, build financial future deserve seven steps.',
#   767: 'truth sees neil strauss draw lessons monogamy, love relationships learned depression, sex addiction treatment, swinger parties science labs, decade becoming one world’s notorious pick-up artists desired single men planet.',
#   768: 'ultimate sales machine legacy chet holmes left help sales staff world, giving 12 key strategies relentlessly focus execute on, order least double sales.',
#   769: 'unexpected joy sober help happier healthier life persuasively revealing many disadvantages alcohol benefits going without permanently.',
#   770: 'uninhabitable earth explains humanity’s complacency negligence put world course soon unlivable unless small part improve care beautiful planet live on.',
#   771: 'untethered soul describes untie self ego, harness inner energy, expand beyond float river life instead blocking fighting it.',
#   772: 'upside irrationality shows many ways act irrational, thinking you’re makes perfect sense, irrational behavior actually beneficial, long use right way.',
#   773: 'upside stress helps change mindset one avoids anxiety costs belief embraces stress normal part life, helps respond better ways actually healthier.',
#   774: 'upside dark side takes look darkest emotions, like anxiety anger, shows real benefits follow underlying character traits, narcissism psychopathy.',
#   775: 'varieties religious experience show spirituality isn’t limited church benefit trying variety religious practices, even identify religion particular.',
#   776: 'war art brings much needed tough love artists, business people creatives spend time battling resistance work actually working, identifying procrastinating forces play pulling rug feet.',
#   777: 'way zen ultimate guide understanding history, principles, benefits zen help us experience mental stillness enjoy life even uncertain times.',
#   778: 'willpower instinct breaks willpower 3 categories, gives science-backed systems improve self-control, break bad habits choose long-term goals instant gratification.',
#   779: 'wisdom crowds researches groups reach better decisions individuals, makes groups smart, dangers group decisions lie, us encourage groups part work together.',
#   780: 'wisdom insecurity self-help classic breaks psychological need stability explains it’s led us right consumerism, won’t solve problem really calm anxiety.',
#   781: 'wisdom life essay arthur schopenhauer’s last published work, breaks happiness three parts explains achieve it.',
#   782: 'world according star wars summary examines unrivaled popularity epic franchise, also learn real world politics, law, economics even ourselves.',
#   783: 'world without us imagines planet earth without us humans, detailing happen nature man-made creations long we’re gone.',
#   784: 'worry-free mind helps free shackles types anxieties identifying come steps need take regain control thinking patterns become mentally healthy again.',
#   785: 'year without pants dives company culture automattic, company behind wordpress.com explains they’ve created culture work employees thrive, creativity flows freely new ideas implemented daily basis.',
#   786: 'yes brain offers parenting techniques give kids open attitude towards life, balance, resilience, insight, empathy.',
#   787: 'theory u helps leaders act based future, past, allows create organizational change global level creative agile methodologies.',
#   788: 'things little bird told twitter co-founder biz stone’s look back years life twitter, draws many lessons business, life society.',
#   789: 'think grow rich curation 13 common habits wealthy successful people, distilled studying 500 individuals course 20 years.',
#   790: 'think like freak teaches reject conventional wisdom often possible, ask right questions everything come own, statistically validated answers, instead relying peoples’ opinions common sense.',
#   791: 'think small gives science-backed secrets following goals, identifying seven key components help use human nature advantage wild success like you’ve never before.',
#   792: 'thinking fast slow shows two systems brain constantly fighting control behavior actions, teaches many ways leads errors memory, judgment decisions, it.',
#   793: 'marketing argues marketing success today’s world comes focusing needs, values, desires target audience, rather spamming many people possible message.',
#   794: 'brain music explains music historically comes from, triggers brain, develop tastes it’s crucial part lives, along makes great musicians great.',
#   795: 'thou shall prosper examines tried true principles age-old, jewish tradition creating life wealth, prosperity integrity, combines examples modern world business, help live successful life.',
#   796: 'thrive shines light missing ingredient perception success, includes well-being, wonder, wisdom giving, goes beyond money power, often drive people right burnout, terrible health unhappiness.',
#   797: 'language glass explains language speak fundamentally alters reality nature, culture language intertwined throughout history.',
#   798: 'time spend guide becoming productive focusing working extra hours instead using time effectively.',
#   799: 'tiny habits shows power applying small changes routine unleash full power habits make life better.',
#   800: 'sell human shows selling part life, matter do, successful salesperson looks like 21st century, practical ideas help convince others honest, natural sustainable way.',
#   801: 'tools titans massive compendium everything tim ferriss learned health, wealth wisdom interviewing 200 world-class performers podcast, tim ferriss show.',
#   802: 'traction roadmap startups achieve exponential growth necessary survive first months years looking 19 ways get traction framework help pick best one startup.',
#   803: 'tribal leadership explains various ways people function within organizations teaches lead change improve organization’s culture.',
#   804: 'tribe mentors collection 100 mini-interviews, world’s successful people share ideas around habits, learning, money, relationships, failure, success, life.',
#   805: 'tribes turns sheepwalker heretic, giving tools start tribe, explaining they’re future business showing too, leader.',
#   806: 'trillion dollar coach help become better leader office sharing life teachings businessman bill campbell helped build multi-billion dollar companies silicon valley.',
#   807: 'trust me, i’m lying marketer’s take influential blogs truly become, that’s something worry about, internet broken, includes confessions gamed system generate press clients.',
#   808: 'trying try explores ancient, chinese philosophy break art spontaneous, help unite mind body, reach state flow, breeze life like leaf river.',
#   809: 'tubes behind-the-scenes look real, tangible, physical heart internet, elusive seemingly invisible technology permeates lives daily basis.',
#   810: 'turning pro inspiring instruction manual that’ll help create work meant dividing life two phases, amateur professional, getting one other.',
#   811: 'uncertainty shows condition knowing nothing fear, birthplace innovation, which, embrace anchoring yourself, unlimited potential growth, wealth happiness.',
#   812: 'unlimited power self-help classic, breaks tony robbins helped top performers achieve highest level use mental physical tactics accomplish biggest goals life.',
#   813: 'unlocking potential guide help leader make difference people’s lives long run learning coach people way brings light greatest strengths capabilities.',
#   814: 'unshakeable distills essence world class investors four core principles follow investing, giving simple rules actionable steps follow make sure finances flourish.',
#   815: 'upheaval enlightens telling stories seven countries fell crises, including got get out, identifies common threads them.',
#   816: 'vagabonding change relationship money travel showing long-term life road isn’t reserved rich people hippies, give tools need start living life adventure, simplicity content.',
#   817: 'walden details henry david thoreau’s two-year stay self-built cabin lake woods, sharing learned solitude, nature, work, thinking fulfillment break modern city life.',
#   818: 'weird parenting wins make better raising kids sharing strange ways fathers mothers success children, helping see intuition might greatest tool disposal.',
#   819: 'color parachute classic job seekers, equipping tools, tips strategies need quickly find right gig today’s fast-moving market.',
#   820: 'every body saying ex-fbi agents guide reading non-verbal cues, help spot others’ true intentions feelings, even mouths saying something different.',
#   821: 'got won’t get helps overcome personality traits behaviors stop achieving even success.',
#   822: 'know sure encourages create life want pursuing excellence, practicing gratitude, leveraging bad experiences become stronger.',
#   823: 'compilation well-researched, science-based answers craziest hypothetical questions imagine.',
#   824: 'eyes don’t see tells shocking unfortunate story public drinking water crisis flint, michigan one woman stood government corruption racism make positive difference city.',
#   825: 'don’t teach harvard business school teaches succeeding business less accumulated theoretical knowledge schooling books, people communication.',
#   826: 'eat teaches us food works inside body feed way better suits biology, making us healthier stronger.',
#   827: 'bad things happen good people explains even best people sometimes suffer adversity, turn pain something meaningful instead lamenting it.',
#   828: 'breath becomes air helps see what’s really important diving paul kalanithi’s life loving neuroscience, literature, meaning, family ended cancer mid-thirties.',
#   829: 'when: scientific secrets perfect timing breaks science time stop guessing things pick best times work, eat, sleep, coffee even quit job.',
#   830: 'things fall apart gives confidence make life’s inevitable setbacks sharing ideas strategies like mindfulness grow resilience come top.',
#   831: 'rob bank collection best freakonomics authors’ blog posts 10 years blogging economics areas life.',
#   832: 'good ideas come describes process innovation similar evolution good ideas shaped time, build existing platforms, require connections, luck, error turn something old something new.',
#   833: 'wherever go, explains mindfulness it’s reserved zen practitioners buddhist monks, giving simple ways practice everyday life, formally informally, helping avoid obstacles way aware self.',
#   834: 'moved cheese tells parable, directly apply life, order stop fearing lies ahead instead thrive environment change uncertainty.',
#   835: 'skyrocket success, happiness, fulfillment areas life identifying you’re looking problems wrong way simply seeking get right people help make difference.',
#   836: 'cry die? helps leave lasting legacy greatness you’re gone giving specific tips become best version kind makes others grateful contributions lives world.',
#   837: '“a” students work “c” students contains robert kiyosaki’s lessons global financial crisis result lack education shows parents become truly money literate teach kids attain financial freedom.',
#   838: 'yelling? improve relationships, professional life, way view world showing arguments aren’t bad, important growing experiences learn make productive.',
#   839: 'sex fun takes humorous look evolution human sex life, explaining way behave sexually often odd, necessary survival.'}}

# %%
df_response = df2.loc[df2['response_cleaned'] == 'anything want teaches build business that’s based are, become anything want be, rather following traditional paths startup corporate culture.']
df_response
# Out:
#                  book                                           response  \
# 76  Anything You Want   anything you want teaches you how to build a ...
#
#                                      response_cleaned
# 76  anything want teaches build business that’s ba...

# %%
df_response.book
# Out:
# 751    The Speed Of Trust
# Name: book, dtype: object

# %%
def clean_query(s):
    wordnet_lemmatizer = WordNetLemmatizer()
    cleaned = nltk.word_tokenize(s.lower())
    cleaned = [i.strip(string.punctuation) for i in cleaned] 
    cleaned = [wordnet_lemmatizer.lemmatize(i) for i in cleaned]
    cleaned_list = [ i for i in cleaned if i not in set(stopwords.words('english') + [''])]
    query = " ".join(cleaned_list)

    return query

# %%
def calculate_bm25(corpus, query):
    tokenized_corpus = [doc.split(" ") for doc in corpus]
    bm25 = BM25Plus(tokenized_corpus, k1=1.25,b=0.35,delta=0.5)

    tokenized_query = query.split(" ")
    top_results = bm25.get_top_n(tokenized_query, corpus, n=1)
    
    return top_results

# %%
response_list = df2['response_cleaned'].tolist()

# %%
what_the_user_said = 'I want to be a doctor'

query_cleaned = clean_query(what_the_user_said)

# %%
returned_clean_response = calculate_bm25(response_list, query_cleaned)
list_to_str = ' '.join(returned_clean_response)
df_response = df2.loc[df2['response_cleaned'] == list_to_str]

# %%
bookname = df_response.iloc[0]['book']

# %%
bookname
# Out:
# 'Anything You Want'
